# %%
#Make MongoDB connection
from pymongo import MongoClient
client = MongoClient('compute-0-11', 27017)

db = client.FacebookChallenge_akar1
collection1 = db.fb_hw
collection2  = db.fb_hw_test
contentsTrain = collection1.find().limit(10000)
contentsTest = collection2.find().limit(10000)

# %%
#Create spark connector
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql import SQLContext
from pyspark import SparkConf, SparkContext

spark = SparkSession.builder \
        .appName("Facebook_nebaditn") \
        .getOrCreate()

sc = spark.sparkContext
sqlContext = SQLContext(sc)

# %%
from bson import json_util, ObjectId
import json
rddSan1 = json.loads(json_util.dumps(contentsTrain))
rddSan2 = json.loads(json_util.dumps(contentsTest))

# %%
#Generate RDD
rddTrain = sc.parallelize(rddSan1)
rddTest = sc.parallelize(rddSan2)

# %%
#Create schema to generate train and test dataframe
schemaTrain = StructType([StructField("Body", StringType(), True), 
                     StructField("Id", IntegerType(), True), 
                     StructField("Tags", StringType(), True),
                     StructField("Title", StringType(), True),
                     StructField("_id", StringType(), True)])
schemaTest = StructType([StructField("Body", StringType(), True), 
                     StructField("Id", IntegerType(), True), 
                     StructField("Title", StringType(), True),
                     StructField("_id", StringType(), True)])

train = sqlContext.createDataFrame(rddTrain, schema=schemaTrain)
test = sqlContext.createDataFrame(rddTest, schema=schemaTest)

# %%
#Print and check the data
train.show()
test.show()
# Out:
# +--------------------+---+--------------------+--------------------+--------------------+
# |                Body| Id|                Tags|               Title|                 _id|
# +--------------------+---+--------------------+--------------------+--------------------+
# |<p>I'd like to ch...|  1|php image-process...|How to check if a...|{$oid=5a047973393...|
# |<p>In my favorite...|  2|             firefox|How can I prevent...|{$oid=5a047973393...|
# |<p>This is probab...|  4|     c# url encoding|How do I replace ...|{$oid=5a047973393...|
# |<pre><code>functi...|  5|php api file-get-...|How to modify who...|{$oid=5a047973393...|
# |<p>I am using a m...|  6|proxy active-dire...|setting proxy in ...|{$oid=5a047973393...|
# |<p>My image is ca...|  7|           core-plot|How to draw barpl...|{$oid=5a047973393...|
# |<p>I've decided t...|  8|c# asp.net window...|How to fetch an X...|{$oid=5a047973393...|
# |<p>Do you know of...|  9|.net javascript c...|.NET library for ...|{$oid=5a047973393...|
# |<p>I'm using SQL ...| 10|sql variables par...|SQL Server : proc...|{$oid=5a047973393...|
# |<p>Some commercia...| 11|.net obfuscation ...|How do commercial...|{$oid=5a047973393...|
# |<p>how can I move...| 13|postfix migration...|Migrate from Mdae...|{$oid=5a047973393...|
# |<p>I am import ma...|  3|r matlab machine-...|R Error Invalid t...|{$oid=5a047973393...|
# |<p>This may sound...| 12|algorithm languag...|Crappy Random Num...|{$oid=5a047973393...|
# |<p>Few month ago ...| 14|documentation lat...|Where can I find ...|{$oid=5a047973393...|
# |<p>When you hit a...| 15|           windows-7|Can I stop window...|{$oid=5a047973393...|
# |<p>A lot of frame...| 16|php url-routing c...|PHP framework URL...|{$oid=5a047973393...|
# |<p>I'm running a ...| 17|   r temporary-files|What creates ".rd...|{$oid=5a047973393...|
# |<p>Hello<br>
# I'm ...| 18|         wpf binding|WPF: multiple con...|{$oid=5a047973393...|
# |<p>Does anyone kn...| 19|javascript code-g...|Play framework au...|{$oid=5a047973393...|
# |<p>=) I need your...| 20|php xml hash mult...|Creating a repeti...|{$oid=5a047973393...|
# +--------------------+---+--------------------+--------------------+--------------------+
# only showing top 20 rows
#
# +--------------------+-------+--------------------+--------------------+
# |                Body|     Id|               Title|                 _id|
# +--------------------+-------+--------------------+--------------------+
# |<p>How do I disab...|6034196|Getting rid of si...|{$oid=5a04827c393...|
# |<p>I've a gateway...|6034197|Nodes inside Cisc...|{$oid=5a04827c393...|
# |<p>After changing...|6034198|Remove old vCente...|{$oid=5a04827c393...|
# |<p>I have a varia...|6034199|Replace <span> el...|{$oid=5a04827c393...|
# |<p>Today i purcha...|6034200|Will PHP included...|{$oid=5a04827c393...|
# |<p>With the follo...|6034201|Where is the acro...|{$oid=5a04827c393...|
# |<p>I am looking f...|6034202|Iterating over th...|{$oid=5a04827c393...|
# |<p>I'm importing ...|6034203|URL Rewriting fro...|{$oid=5a04827c393...|
# |<p>How can I alph...|6034219|Alphabetised Word...|{$oid=5a04827c393...|
# |<p>I am working o...|6034204|Create Non-Cultur...|{$oid=5a04827c393...|
# |<p>Im using cocos...|6034205|cocos2d: Handelin...|{$oid=5a04827c393...|
# |<p>Are there stan...|6034206|Are there standar...|{$oid=5a04827c393...|
# |<p>I just compile...|6034207|Upgrade ScriptSha...|{$oid=5a04827c393...|
# |<p>How can I auto...|6034208|How can I auto-up...|{$oid=5a04827c393...|
# |<p>I have 3 table...|6034209|how to delete fro...|{$oid=5a04827c393...|
# |<p>Suppose, I hav...|6034210|Get number of ele...|{$oid=5a04827c393...|
# |<p>I would like a...|6034211|can XInclude be u...|{$oid=5a04827c393...|
# |<p>I have my two ...|6034212|Printing from a P...|{$oid=5a04827c393...|
# |<p>We have a webs...|6034213|How can I set the...|{$oid=5a04827c393...|
# |<p>I have two cla...|6034214|Nesting CriteriaB...|{$oid=5a04827c393...|
# +--------------------+-------+--------------------+--------------------+
# only showing top 20 rows

# %%
# Remove HTML Tags from the Body text
#Here I have used a library beautiful soup to remove the HTML tags from the body section in train and test
from bs4 import BeautifulSoup
from pyspark.sql.functions import udf
from pyspark.sql.types import *

train = train.rdd.map(lambda x: (x[0], x[1], x[2], x[3], x[4], BeautifulSoup(x[0]).text))
train = train.toDF()
test = test.rdd.map(lambda x: (x[0], x[1], x[2], x[3], BeautifulSoup(x[0]).text))
test =  test.toDF()

# %%
#Check the new dataframe 
train.show()
test.show()
# Out:
# +--------------------+---+--------------------+--------------------+--------------------+--------------------+
# |                  _1| _2|                  _3|                  _4|                  _5|                  _6|
# +--------------------+---+--------------------+--------------------+--------------------+--------------------+
# |<p>I'd like to ch...|  1|php image-process...|How to check if a...|{$oid=5a047973393...|I'd like to check...|
# |<p>In my favorite...|  2|             firefox|How can I prevent...|{$oid=5a047973393...|In my favorite ed...|
# |<p>This is probab...|  4|     c# url encoding|How do I replace ...|{$oid=5a047973393...|This is probably ...|
# |<pre><code>functi...|  5|php api file-get-...|How to modify who...|{$oid=5a047973393...|function modify(....|
# |<p>I am using a m...|  6|proxy active-dire...|setting proxy in ...|{$oid=5a047973393...|I am using a mach...|
# |<p>My image is ca...|  7|           core-plot|How to draw barpl...|{$oid=5a047973393...|My image is canno...|
# |<p>I've decided t...|  8|c# asp.net window...|How to fetch an X...|{$oid=5a047973393...|I've decided to c...|
# |<p>Do you know of...|  9|.net javascript c...|.NET library for ...|{$oid=5a047973393...|Do you know of a ...|
# |<p>I'm using SQL ...| 10|sql variables par...|SQL Server : proc...|{$oid=5a047973393...|I'm using SQL Ser...|
# |<p>Some commercia...| 11|.net obfuscation ...|How do commercial...|{$oid=5a047973393...|Some commercial o...|
# |<p>how can I move...| 13|postfix migration...|Migrate from Mdae...|{$oid=5a047973393...|how can I move In...|
# |<p>I am import ma...|  3|r matlab machine-...|R Error Invalid t...|{$oid=5a047973393...|I am import matla...|
# |<p>This may sound...| 12|algorithm languag...|Crappy Random Num...|{$oid=5a047973393...|This may sound li...|
# |<p>Few month ago ...| 14|documentation lat...|Where can I find ...|{$oid=5a047973393...|Few month ago I s...|
# |<p>When you hit a...| 15|           windows-7|Can I stop window...|{$oid=5a047973393...|When you hit alt ...|
# |<p>A lot of frame...| 16|php url-routing c...|PHP framework URL...|{$oid=5a047973393...|A lot of framewor...|
# |<p>I'm running a ...| 17|   r temporary-files|What creates ".rd...|{$oid=5a047973393...|I'm running a ser...|
# |<p>Hello<br>
# I'm ...| 18|         wpf binding|WPF: multiple con...|{$oid=5a047973393...|Hello
# I'm trying ...|
# |<p>Does anyone kn...| 19|javascript code-g...|Play framework au...|{$oid=5a047973393...|Does anyone know ...|
# |<p>=) I need your...| 20|php xml hash mult...|Creating a repeti...|{$oid=5a047973393...|=) I need your ki...|
# +--------------------+---+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows
#
# +--------------------+-------+--------------------+--------------------+--------------------+
# |                  _1|     _2|                  _3|                  _4|                  _5|
# +--------------------+-------+--------------------+--------------------+--------------------+
# |<p>How do I disab...|6034196|Getting rid of si...|{$oid=5a04827c393...|How do I disable ...|
# |<p>I've a gateway...|6034197|Nodes inside Cisc...|{$oid=5a04827c393...|I've a gateway-to...|
# |<p>After changing...|6034198|Remove old vCente...|{$oid=5a04827c393...|After changing ou...|
# |<p>I have a varia...|6034199|Replace <span> el...|{$oid=5a04827c393...|I have a variable...|
# |<p>Today i purcha...|6034200|Will PHP included...|{$oid=5a04827c393...|Today i purchase ...|
# |<p>With the follo...|6034201|Where is the acro...|{$oid=5a04827c393...|With the followin...|
# |<p>I am looking f...|6034202|Iterating over th...|{$oid=5a04827c393...|I am looking for ...|
# |<p>I'm importing ...|6034203|URL Rewriting fro...|{$oid=5a04827c393...|I'm importing cla...|
# |<p>How can I alph...|6034219|Alphabetised Word...|{$oid=5a04827c393...|How can I alphabe...|
# |<p>I am working o...|6034204|Create Non-Cultur...|{$oid=5a04827c393...|I am working on a...|
# |<p>Im using cocos...|6034205|cocos2d: Handelin...|{$oid=5a04827c393...|Im using cocos2d-...|
# |<p>Are there stan...|6034206|Are there standar...|{$oid=5a04827c393...|Are there standar...|
# |<p>I just compile...|6034207|Upgrade ScriptSha...|{$oid=5a04827c393...|I just compiled t...|
# |<p>How can I auto...|6034208|How can I auto-up...|{$oid=5a04827c393...|How can I automat...|
# |<p>I have 3 table...|6034209|how to delete fro...|{$oid=5a04827c393...|I have 3 tables:
# ...|
# |<p>Suppose, I hav...|6034210|Get number of ele...|{$oid=5a04827c393...|Suppose, I have t...|
# |<p>I would like a...|6034211|can XInclude be u...|{$oid=5a04827c393...|I would like a po...|
# |<p>I have my two ...|6034212|Printing from a P...|{$oid=5a04827c393...|I have my two Win...|
# |<p>We have a webs...|6034213|How can I set the...|{$oid=5a04827c393...|We have a website...|
# |<p>I have two cla...|6034214|Nesting CriteriaB...|{$oid=5a04827c393...|I have two classe...|
# +--------------------+-------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
#Filter columns from the data frame
workingTrain = train.selectExpr("_2 as ID", "_6 as Body", "_3 as Tags", "_4 as Title")
workingTest = test.selectExpr("_2 as ID", "_5 as Body", "_3 as Title")

# %%
#Again check the data frame
workingTrain.show()
workingTest.show()
# Out:
# +---+--------------------+--------------------+--------------------+
# | ID|                Body|                Tags|               Title|
# +---+--------------------+--------------------+--------------------+
# |  1|I'd like to check...|php image-process...|How to check if a...|
# |  2|In my favorite ed...|             firefox|How can I prevent...|
# |  4|This is probably ...|     c# url encoding|How do I replace ...|
# |  5|function modify(....|php api file-get-...|How to modify who...|
# |  6|I am using a mach...|proxy active-dire...|setting proxy in ...|
# |  7|My image is canno...|           core-plot|How to draw barpl...|
# |  8|I've decided to c...|c# asp.net window...|How to fetch an X...|
# |  9|Do you know of a ...|.net javascript c...|.NET library for ...|
# | 10|I'm using SQL Ser...|sql variables par...|SQL Server : proc...|
# | 11|Some commercial o...|.net obfuscation ...|How do commercial...|
# | 13|how can I move In...|postfix migration...|Migrate from Mdae...|
# |  3|I am import matla...|r matlab machine-...|R Error Invalid t...|
# | 12|This may sound li...|algorithm languag...|Crappy Random Num...|
# | 14|Few month ago I s...|documentation lat...|Where can I find ...|
# | 15|When you hit alt ...|           windows-7|Can I stop window...|
# | 16|A lot of framewor...|php url-routing c...|PHP framework URL...|
# | 17|I'm running a ser...|   r temporary-files|What creates ".rd...|
# | 18|Hello
# I'm trying ...|         wpf binding|WPF: multiple con...|
# | 19|Does anyone know ...|javascript code-g...|Play framework au...|
# | 20|=) I need your ki...|php xml hash mult...|Creating a repeti...|
# +---+--------------------+--------------------+--------------------+
# only showing top 20 rows
#
# +-------+--------------------+--------------------+
# |     ID|                Body|               Title|
# +-------+--------------------+--------------------+
# |6034196|How do I disable ...|Getting rid of si...|
# |6034197|I've a gateway-to...|Nodes inside Cisc...|
# |6034198|After changing ou...|Remove old vCente...|
# |6034199|I have a variable...|Replace <span> el...|
# |6034200|Today i purchase ...|Will PHP included...|
# |6034201|With the followin...|Where is the acro...|
# |6034202|I am looking for ...|Iterating over th...|
# |6034203|I'm importing cla...|URL Rewriting fro...|
# |6034219|How can I alphabe...|Alphabetised Word...|
# |6034204|I am working on a...|Create Non-Cultur...|
# |6034205|Im using cocos2d-...|cocos2d: Handelin...|
# |6034206|Are there standar...|Are there standar...|
# |6034207|I just compiled t...|Upgrade ScriptSha...|
# |6034208|How can I automat...|How can I auto-up...|
# |6034209|I have 3 tables:
# ...|how to delete fro...|
# |6034210|Suppose, I have t...|Get number of ele...|
# |6034211|I would like a po...|can XInclude be u...|
# |6034212|I have my two Win...|Printing from a P...|
# |6034213|We have a website...|How can I set the...|
# |6034214|I have two classe...|Nesting CriteriaB...|
# +-------+--------------------+--------------------+
# only showing top 20 rows

# %%
#Select particular columns
workingTrain = workingTrain.selectExpr("Body", "Title", "Tags")
workingTest = workingTest.selectExpr("ID", "Title", "Body")

# %%
workingTrain.show()
workingTest.show()
# Out:
# +--------------------+--------------------+--------------------+
# |                Body|               Title|                Tags|
# +--------------------+--------------------+--------------------+
# |I'd like to check...|How to check if a...|php image-process...|
# |In my favorite ed...|How can I prevent...|             firefox|
# |This is probably ...|How do I replace ...|     c# url encoding|
# |function modify(....|How to modify who...|php api file-get-...|
# |I am using a mach...|setting proxy in ...|proxy active-dire...|
# |My image is canno...|How to draw barpl...|           core-plot|
# |I've decided to c...|How to fetch an X...|c# asp.net window...|
# |Do you know of a ...|.NET library for ...|.net javascript c...|
# |I'm using SQL Ser...|SQL Server : proc...|sql variables par...|
# |Some commercial o...|How do commercial...|.net obfuscation ...|
# |how can I move In...|Migrate from Mdae...|postfix migration...|
# |I am import matla...|R Error Invalid t...|r matlab machine-...|
# |This may sound li...|Crappy Random Num...|algorithm languag...|
# |Few month ago I s...|Where can I find ...|documentation lat...|
# |When you hit alt ...|Can I stop window...|           windows-7|
# |A lot of framewor...|PHP framework URL...|php url-routing c...|
# |I'm running a ser...|What creates ".rd...|   r temporary-files|
# |Hello
# I'm trying ...|WPF: multiple con...|         wpf binding|
# |Does anyone know ...|Play framework au...|javascript code-g...|
# |=) I need your ki...|Creating a repeti...|php xml hash mult...|
# +--------------------+--------------------+--------------------+
# only showing top 20 rows
#
# +-------+--------------------+--------------------+
# |     ID|               Title|                Body|
# +-------+--------------------+--------------------+
# |6034196|Getting rid of si...|How do I disable ...|
# |6034197|Nodes inside Cisc...|I've a gateway-to...|
# |6034198|Remove old vCente...|After changing ou...|
# |6034199|Replace <span> el...|I have a variable...|
# |6034200|Will PHP included...|Today i purchase ...|
# |6034201|Where is the acro...|With the followin...|
# |6034202|Iterating over th...|I am looking for ...|
# |6034203|URL Rewriting fro...|I'm importing cla...|
# |6034219|Alphabetised Word...|How can I alphabe...|
# |6034204|Create Non-Cultur...|I am working on a...|
# |6034205|cocos2d: Handelin...|Im using cocos2d-...|
# |6034206|Are there standar...|Are there standar...|
# |6034207|Upgrade ScriptSha...|I just compiled t...|
# |6034208|How can I auto-up...|How can I automat...|
# |6034209|how to delete fro...|I have 3 tables:
# ...|
# |6034210|Get number of ele...|Suppose, I have t...|
# |6034211|can XInclude be u...|I would like a po...|
# |6034212|Printing from a P...|I have my two Win...|
# |6034213|How can I set the...|We have a website...|
# |6034214|Nesting CriteriaB...|I have two classe...|
# +-------+--------------------+--------------------+
# only showing top 20 rows

# %%
#Remove the stop words from the body
from pyspark.ml.feature import StopWordsRemover
from pyspark.ml.feature import Tokenizer, RegexTokenizer
from pyspark.sql.functions import col, udf
from pyspark.sql.types import IntegerType
#Tokenize the body column
tokenizer = Tokenizer(inputCol = "Body" , outputCol = "tokenizedBody")
workingTrain = tokenizer.transform(workingTrain) # For the train data
workingTest = tokenizer.transform(workingTest) # For the train data
remover = StopWordsRemover(inputCol = "tokenizedBody", outputCol = "filteredCol")
workingTrain = remover.transform(workingTrain) #For Train data
workingTest = remover.transform(workingTest) #For Test data

# %%
workingTrain.show()
workingTest.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+
# |                Body|               Title|                Tags|       tokenizedBody|         filteredCol|
# +--------------------+--------------------+--------------------+--------------------+--------------------+
# |I'd like to check...|How to check if a...|php image-process...|[i'd, like, to, c...|[like, check, upl...|
# |In my favorite ed...|How can I prevent...|             firefox|[in, my, favorite...|[favorite, editor...|
# |This is probably ...|How do I replace ...|     c# url encoding|[this, is, probab...|[probably, simple...|
# |function modify(....|How to modify who...|php api file-get-...|[function, modify...|[function, modify...|
# |I am using a mach...|setting proxy in ...|proxy active-dire...|[i, am, using, a,...|[using, machine, ...|
# |My image is canno...|How to draw barpl...|           core-plot|[my, image, is, c...|[image, post, , l...|
# |I've decided to c...|How to fetch an X...|c# asp.net window...|[i've, decided, t...|[decided, convert...|
# |Do you know of a ...|.NET library for ...|.net javascript c...|[do, you, know, o...|[know, .net, libr...|
# |I'm using SQL Ser...|SQL Server : proc...|sql variables par...|[i'm, using, sql,...|[using, sql, serv...|
# |Some commercial o...|How do commercial...|.net obfuscation ...|[some, commercial...|[commercial, obfu...|
# |how can I move In...|Migrate from Mdae...|postfix migration...|[how, can, i, mov...|[move, inbox/sent...|
# |I am import matla...|R Error Invalid t...|r matlab machine-...|[i, am, import, m...|[import, matlab, ...|
# |This may sound li...|Crappy Random Num...|algorithm languag...|[this, may, sound...|[may, sound, like...|
# |Few month ago I s...|Where can I find ...|documentation lat...|[few, month, ago,...|[month, ago, saw,...|
# |When you hit alt ...|Can I stop window...|           windows-7|[when, you, hit, ...|[hit, alt, tab, w...|
# |A lot of framewor...|PHP framework URL...|php url-routing c...|[a, lot, of, fram...|[lot, frameworks,...|
# |I'm running a ser...|What creates ".rd...|   r temporary-files|[i'm, running, a,...|[running, server,...|
# |Hello
# I'm trying ...|WPF: multiple con...|         wpf binding|[hello, i'm, tryi...|[hello, trying, c...|
# |Does anyone know ...|Play framework au...|javascript code-g...|[does, anyone, kn...|[anyone, know, go...|
# |=) I need your ki...|Creating a repeti...|php xml hash mult...|[=), i, need, you...|[=), need, kindly...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows
#
# +-------+--------------------+--------------------+--------------------+--------------------+
# |     ID|               Title|                Body|       tokenizedBody|         filteredCol|
# +-------+--------------------+--------------------+--------------------+--------------------+
# |6034196|Getting rid of si...|How do I disable ...|[how, do, i, disa...|[disable, site-sp...|
# |6034197|Nodes inside Cisc...|I've a gateway-to...|[i've, a, gateway...|[gateway-to-gatew...|
# |6034198|Remove old vCente...|After changing ou...|[after, changing,...|[changing, vcente...|
# |6034199|Replace <span> el...|I have a variable...|[i, have, a, vari...|[variable, lifted...|
# |6034200|Will PHP included...|Today i purchase ...|[today, i, purcha...|[today, purchase,...|
# |6034201|Where is the acro...|With the followin...|[with, the, follo...|[following, code,...|
# |6034202|Iterating over th...|I am looking for ...|[i, am, looking, ...|[looking, way, it...|
# |6034203|URL Rewriting fro...|I'm importing cla...|[i'm, importing, ...|[importing, class...|
# |6034219|Alphabetised Word...|How can I alphabe...|[how, can, i, alp...|[alphabetise, (by...|
# |6034204|Create Non-Cultur...|I am working on a...|[i, am, working, ...|[working, asp.net...|
# |6034205|cocos2d: Handelin...|Im using cocos2d-...|[im, using, cocos...|[im, using, cocos...|
# |6034206|Are there standar...|Are there standar...|[are, there, stan...|[standard, practi...|
# |6034207|Upgrade ScriptSha...|I just compiled t...|[i, just, compile...|[compiled, master...|
# |6034208|How can I auto-up...|How can I automat...|[how, can, i, aut...|[automatically, u...|
# |6034209|how to delete fro...|I have 3 tables:
# ...|[i, have, 3, tabl...|[3, tables:, , ta...|
# |6034210|Get number of ele...|Suppose, I have t...|[suppose,, i, hav...|[suppose,, follow...|
# |6034211|can XInclude be u...|I would like a po...|[i, would, like, ...|[like, portable, ...|
# |6034212|Printing from a P...|I have my two Win...|[i, have, my, two...|[two, windows, pc...|
# |6034213|How can I set the...|We have a website...|[we, have, a, web...|[website, virtual...|
# |6034214|Nesting CriteriaB...|I have two classe...|[i, have, two, cl...|[two, classes, b,...|
# +-------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
#Tokenize the Tags
tagTokenizer = Tokenizer(inputCol="Tags", outputCol="tokenizedTags")
workingTrain = tagTokenizer.transform(workingTrain)
#workingTrain.show()

# %%
#Tokenize the Title
titleTokenizer = Tokenizer(inputCol="Title", outputCol="tokenizedTitle")
workingTrain = titleTokenizer.transform(workingTrain)
workingTest = titleTokenizer.transform(workingTest)

# %%
#Remove stop words from the Tokenized title
titleRemover = StopWordsRemover(inputCol = "tokenizedTitle", outputCol = "filteredTitle")
workingTrain = titleRemover.transform(workingTrain) #For Train data
workingTest = titleRemover.transform(workingTest) #For Test data

# %%
workingTrain = workingTrain.selectExpr("filteredCol as tokenizedBody", "filteredTitle as tokenizedTitle","tokenizedTags")
workingTest = workingTest.selectExpr("ID", "filteredCol as tokenizedBody", "filteredTitle as tokenizedTitle")

# %%
#Check the Dataframe
workingTrain.show()
workingTest.show()
# Out:
# +--------------------+--------------------+--------------------+
# |       tokenizedBody|      tokenizedTitle|       tokenizedTags|
# +--------------------+--------------------+--------------------+
# |[like, check, upl...|[check, uploaded,...|[php, image-proce...|
# |[favorite, editor...|[prevent, firefox...|           [firefox]|
# |[probably, simple...|[replace, special...| [c#, url, encoding]|
# |[function, modify...|[modify, whois, c...|[php, api, file-g...|
# |[using, machine, ...|[setting, proxy, ...|[proxy, active-di...|
# |[image, post, , l...|[draw, barplot, w...|         [core-plot]|
# |[decided, convert...|[fetch, xml, feed...|[c#, asp.net, win...|
# |[know, .net, libr...|[.net, library, g...|[.net, javascript...|
# |[using, sql, serv...|[sql, server, :, ...|[sql, variables, ...|
# |[commercial, obfu...|[commercial, obfu...|[.net, obfuscatio...|
# |[move, inbox/sent...|[migrate, mdaemon...|[postfix, migrati...|
# |[import, matlab, ...|[r, error, invali...|[r, matlab, machi...|
# |[may, sound, like...|[crappy, random, ...|[algorithm, langu...|
# |[month, ago, saw,...|[find, latex3, ma...|[documentation, l...|
# |[hit, alt, tab, w...|[stop, windows, 7...|         [windows-7]|
# |[lot, frameworks,...|[php, framework, ...|[php, url-routing...|
# |[running, server,...|[creates, ".rds",...|[r, temporary-files]|
# |[hello, trying, c...|[wpf:, multiple, ...|      [wpf, binding]|
# |[anyone, know, go...|[play, framework,...|[javascript, code...|
# |[=), need, kindly...|[creating, repeti...|[php, xml, hash, ...|
# +--------------------+--------------------+--------------------+
# only showing top 20 rows
#
# +-------+--------------------+--------------------+
# |     ID|       tokenizedBody|      tokenizedTitle|
# +-------+--------------------+--------------------+
# |6034196|[disable, site-sp...|[getting, rid, si...|
# |6034197|[gateway-to-gatew...|[nodes, inside, c...|
# |6034198|[changing, vcente...|[remove, old, vce...|
# |6034199|[variable, lifted...|[replace, <span>,...|
# |6034200|[today, purchase,...|[php, included, h...|
# |6034201|[following, code,...|[acronym, menu, v...|
# |6034202|[looking, way, it...|[iterating, regis...|
# |6034203|[importing, class...|[url, rewriting, ...|
# |6034219|[alphabetise, (by...|[alphabetised, wo...|
# |6034204|[working, asp.net...|[create, non-cult...|
# |6034205|[im, using, cocos...|[cocos2d:, handel...|
# |6034206|[standard, practi...|[standard, practi...|
# |6034207|[compiled, master...|[upgrade, scripts...|
# |6034208|[automatically, u...|[auto-update, new...|
# |6034209|[3, tables:, , ta...|[delete, multiple...|
# |6034210|[suppose,, follow...|[get, number, ele...|
# |6034211|[like, portable, ...|[xinclude, used, ...|
# |6034212|[two, windows, pc...|[printing, pc, ma...|
# |6034213|[website, virtual...|[set, default, pa...|
# |6034214|[two, classes, b,...|[nesting, criteri...|
# +-------+--------------------+--------------------+
# only showing top 20 rows

# %%
#The intuition behind applying ngrams was to try the body and tag with uni and bigram, but due to slow cluster, this step was not completing.
#Limiting it to unigram.
from pyspark.ml.feature import NGram
ngramTags = NGram(n=1, inputCol="tokenizedTags", outputCol="ngramsTags")
workingTrain = ngramTags.transform(workingTrain)

# %%
workingTrain.select("ngramsTags").show(1,False)
# Out:
# +--------------------------------------------------------+
# |ngramsTags                                              |
# +--------------------------------------------------------+
# |[php, image-processing, file-upload, upload, mime-types]|
# +--------------------------------------------------------+
# only showing top 1 row

# %%
workingTrain = workingTrain.selectExpr("tokenizedBody", "tokenizedTitle","ngramsTags")

# %%
workingTrain.show()
# Out:
# +--------------------+--------------------+--------------------+
# |       tokenizedBody|      tokenizedTitle|          ngramsTags|
# +--------------------+--------------------+--------------------+
# |[like, check, upl...|[check, uploaded,...|[php, image-proce...|
# |[favorite, editor...|[prevent, firefox...|           [firefox]|
# |[probably, simple...|[replace, special...| [c#, url, encoding]|
# |[function, modify...|[modify, whois, c...|[php, api, file-g...|
# |[using, machine, ...|[setting, proxy, ...|[proxy, active-di...|
# |[image, post, , l...|[draw, barplot, w...|         [core-plot]|
# |[decided, convert...|[fetch, xml, feed...|[c#, asp.net, win...|
# |[know, .net, libr...|[.net, library, g...|[.net, javascript...|
# |[using, sql, serv...|[sql, server, :, ...|[sql, variables, ...|
# |[commercial, obfu...|[commercial, obfu...|[.net, obfuscatio...|
# |[move, inbox/sent...|[migrate, mdaemon...|[postfix, migrati...|
# |[import, matlab, ...|[r, error, invali...|[r, matlab, machi...|
# |[may, sound, like...|[crappy, random, ...|[algorithm, langu...|
# |[month, ago, saw,...|[find, latex3, ma...|[documentation, l...|
# |[hit, alt, tab, w...|[stop, windows, 7...|         [windows-7]|
# |[lot, frameworks,...|[php, framework, ...|[php, url-routing...|
# |[running, server,...|[creates, ".rds",...|[r, temporary-files]|
# |[hello, trying, c...|[wpf:, multiple, ...|      [wpf, binding]|
# |[anyone, know, go...|[play, framework,...|[javascript, code...|
# |[=), need, kindly...|[creating, repeti...|[php, xml, hash, ...|
# +--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
#Convert Spark Dataframe to Pandas
workingTrain = workingTrain.toPandas()
workingTest = workingTest.toPandas()

# %%
#Display Pandas
#Converted the dataframe to Pandas to apply the scikit library
workingTrain
workingTest
# Out:
#            ID                                      tokenizedBody  \
# 0     6034196  [disable, site-specific, hotkeys, (and, if), a...
# 1     6034197  [gateway-to-gateway, vpn, setup, linksys, rv04...
# 2     6034198  [changing, vcenter, servers, recently,, old, v...
# 3     6034199  [variable, lifted, contents, of,, div, page,, ...
# 4     6034200  [today, purchase, small, cms, system., cms, tr...
# 5     6034201  [following, code, visual, studio, +, resharper...
# 6     6034202  [looking, way, iterate, registers, yardoc, @ma...
# 7     6034203  [importing, classic, asp, pages, new, sitefini...
# 8     6034219      [alphabetise, (by, title), wordpress, posts?]
# 9     6034204  [working, asp.net, application, company, speci...
# 10    6034205  [im, using, cocos2d-x, developing, linux, appl...
# 11    6034206  [standard, practices, writing, spec, software,...
# 12    6034207  [compiled, master, branch, scriptsharp, machin...
# 13    6034208  [automatically, update, news, feed, site, with...
# 14    6034209  [3, tables:, , table, events., fields, event_i...
# 15    6034210  [suppose,, following, code:, \documentclass{ar...
# 16    6034211  [like, portable, solution, creating, multiply,...
# 17    6034212  [two, windows, pcs, hooked, printer, connected...
# 18    6034213  [website, virtual, directory, containing, secu...
# 19    6034214  [two, classes, b, transfer, object, to., like,...
# 20    6034215  [like, launch, url, installer, finishes., adde...
# 21    6034216  [new, vault, huge, fan, far,, need, something,...
# 22    6034217  [add, checkbox, fuctionality, checked, email, ...
# 23    6034218  [according, spec,, complex, child, properties,...
# 24    6034220  [using, php,, extjs, ajax, store., , sends, da...
# 25    6034221  [code:, <script, src="http://ajax.googleapis.c...
# 26    6034222  [need, small,, lightweight, operating, system,...
# 27    6034223  [three, different, hp, desktops, days, now., ,...
# 28    6034224  [like, completely, disable, fading, edge, top,...
# 29    6034225  [java.lang.iterator, interface, 3, methods:, h...
# ...       ...                                                ...
# 9970  6044166  [untaring, command, tar, -pxvzf, filename.tar....
# 9971  6044167  [question, regarding, model, binding, mvc, say...
# 9972  6044168  [silverlight, (though, think, applicable, wpf,...
# 9973  6044169  [seems, simple, question, unfortunately, find,...
# 9974  6044170  [downloaded, live, wallpaper:, https://play.go...
# 9975  6044171  [given, following, scenario:, html, form, chan...
# 9976  6044172  [parent/child, form., example,, parent, table,...
# 9977  6044173  [want, read, specific, string, text, file, out...
# 9978  6044174  [try, s_server, connect, java, client, see, co...
# 9979  6044175  [suppose, develop, simple, data, model, java, ...
# 9980  6044176  [detect, return, type, parameter, types, nulla...
# 9981  6044177  [way, know, someone, using, 24, hour, 12, hour...
# 9982  6044178  [var, n:number, =, 1;, trace("n, number:", +, ...
# 9983  6044179  [want, write, text, currently, selected, appli...
# 9984  6044180  [trying, achive, following, programmatically, ...
# 9985  6044181  [type, question, posted, long, ago, doubts, jq...
# 9986  6044182  [making, android, application, needs, use, lis...
# 9987  6044183  [developing, applications, clojure, +, java, u...
# 9988  6044184  [come, strange, problem, use, visual, studio, ...
# 9989  6044185  [trying, write, sh, script, run, one, download...
# 9990  6044186  [using, sqlite3, ios, development., found, str...
# 9991  6044187  [code,, loop, inside, try, catch., error, enco...
# 9992  6044188  [encountering, unexpected, error, ("inconverti...
# 9993  6044189  [using, symfony2, knpmenubundle, installed, su...
# 9994  6044190  [function, breaks, somewhere, line, 1433, extj...
# 9995  6044191  [want, use, number, shapedrawables, applicatio...
# 9996  6044192  [web-base, application., task, done, 2, admins...
# 9997  6044193  [container, full, tiles, assets, serves, map.,...
# 9998  6044194  [control, browser's, native, textarea, highlig...
# 9999  6044195  [possible, host, gwt-compiled, web, applicatio...
#
#                                          tokenizedTitle
# 0                [getting, rid, site-specific, hotkeys]
# 1     [nodes, inside, cisco, vpn., incoming, ssh, re...
# 2     [remove, old, vcenter, servers, vmware, vspher...
# 3     [replace, <span>, element, var, containing, html]
# 4          [php, included, html, content, affect, seo?]
# 5                [acronym, menu, visual, studio, 2010?]
# 6              [iterating, registers, yardoc, `@macro`]
# 7      [url, rewriting, winforms, console, application]
# 8                      [alphabetised, wordpress, posts]
# 9     [create, non-culture, based, resourcemanager, ...
# 10       [cocos2d:, handeling, keyboard, events, linux]
# 11    [standard, practices, writing, spec, software,...
# 12    [upgrade, scriptsharp, 0.7.4, 0.7.6, throws, "...
# 13    [auto-update, news, feed, javascript, without,...
# 14                            [delete, multiple, table]
# 15                   [get, number, elements, enumerate]
# 16                     [xinclude, used, stream, input?]
# 17                   [printing, pc, mac, prints, light]
# 18               [set, default, page, https, requests?]
# 19    [nesting, criteriabuilder.construct, expressio...
# 20    [launch, web, page, installation, visual, stud...
# 21    [pull, files, project, per, version, label, va...
# 22           [newsletter, option, contact, us, magento]
# 23         [asp.net, mvc, 2, validate, nested, objects]
# 24                         [retrieve, request, payload]
# 25                      [jquery, error, draggable, 1.8]
# 26          [small, operating, system, jvm, x, system?]
# 27    [several, different, windows, xp, desktops, re...
# 28                     [android, disable, fading, edge]
# 29       [exceptions, implementing, java.lang.iterator]
# ...                                                 ...
# 9970                        [tar, exiting, failure...?]
# 9971                  [mvc, model, binding, limitation]
# 9972  [start, storyboards, one, another, list, datab...
# 9973     [update, last, 10, records, php, mysql, table]
# 9974  [[android, live, wallpaper]how, start, activit...
# 9975                 [submitting, passwords, via, ajax]
# 9976                  [store, detail, data, javascript]
# 9977      [read, string, text, file, using, powershell]
# 9978                     [java, program, openssl, work]
# 9979                  [basic, question, data, modeling]
# 9980  [detecting, function, object, (functor), lambd...
# 9981            [zend, locale, get, 12, 24, hour, time]
# 9982  [actionscript,, tell, whether, type, number, n...
# 9983                   [writing, text, another, window]
# 9984  [laying, views, relativelayout, programmatically]
# 9985                      [two, jquery, conflicts, php]
# 9986                         [using, listview, android]
# 9987  [maven, dependencies, clojure, libraries, github]
# 9988  [vs2012, :, error, unit, test, :, assert::aree...
# 9989  [sh, script, move, files, one, dir, another, d...
# 9990                                   [speed, sqlite3]
# 9991                    [c#, error, handling, question]
# 9992  ["inconvertible, types", using, implementation...
# 9993  [symfony2:, knpmenubundle:, menu, "main", defi...
# 9994                 [getting, scope, function, caller]
# 9995              [multiple, drawables, one, xml, file]
# 9996                         [php,, mysql, performance]
# 9997        [maintain, camera, position, zooming, out?]
# 9998  [get, rid, browser's, native, textarea, highli...
# 9999  [possible, host, gwt-compiled, web, applicatio...
#
# [10000 rows x 3 columns]

# %%
#Reference: https://stackoverflow.com/questions/10526579/use-scikit-learn-to-classify-into-multiple-categories
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import LinearSVC
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import MultiLabelBinarizer

classifier = OneVsRestClassifier(LinearSVC())
X_train = np.array(workingTrain["tokenizedBody"])
X_test = np.array(workingTest["tokenizedBody"])

# %%
y_train_text= np.array(workingTrain["ngramsTags"])

# %%
mlb = MultiLabelBinarizer()
Y = mlb.fit_transform(y_train_text)

# %%
classifier = Pipeline([
    ('vectorizer', CountVectorizer(tokenizer=lambda doc: doc,lowercase=False)),
    ('tfidf', TfidfTransformer()),
    ('clf', OneVsRestClassifier(LinearSVC()))])

# %%
classifier.fit(X_train, Y)
# Out:
# Pipeline(memory=None,
#      steps=[('vectorizer', CountVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=False, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#    ...lti_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0),
#           n_jobs=1))])

# %%
predicted = classifier.predict(X_train)

# %%
all_labels = mlb.inverse_transform(predicted)

# %%
#Print the predicted labels
all_labels
# Out:
# [(u'file-upload', u'image-processing', u'mime-types', u'php', u'upload'),
#  (u'firefox',),
#  (u'c#', u'encoding', u'url'),
#  (u'api', u'file-get-contents', u'php'),
#  (u'active-directory', u'jmeter', u'proxy'),
#  (u'core-plot',),
#  (u'asp.net', u'c#', u'windows-phone-7'),
#  (u'.net', u'code-generation', u'javascript'),
#  (u'calls', u'parameters', u'procedure', u'sql', u'variables'),
#  (u'.net', u'obfuscation', u'reflector'),
#  (u'mdaemon', u'migration', u'postfix'),
#  (u'machine-learning', u'matlab', u'r'),
#  (u'algorithm', u'language-agnostic', u'random'),
#  (u'documentation', u'expl3', u'latex3'),
#  (u'windows-7',),
#  (u'conventions', u'php', u'url-routing'),
#  (),
#  (),
#  (u'code-generation', u'javascript', u'minify', u'playframework'),
#  (u'hash',
#   u'multidimensional-array',
#   u'php',
#   u'simplexml-load-string',
#   u'xml'),
#  (u'cancer', u'healthcare', u'medical-science'),
#  (u'.net', u'c#', u'linq'),
#  (),
#  (u'iis',),
#  (u'c#',),
#  (u'haskell',),
#  (u'gnu', u'makefile', u'visual-studio'),
#  (u'html', u'line-breaks', u'semantic'),
#  (u'bounds-checker', u'c++', u'gcc', u'stl'),
#  (),
#  (u'asp.net-mvc-4', u'asp.net-optimization', u'bundle', u'css', u'jquery-ui'),
#  (u'c#', u'entity-framework-4'),
#  (),
#  (u'apk', u'monodroid'),
#  (u'mvvm', u'wpf'),
#  (u'calculus', u'homework', u'polar-coordinates'),
#  (u'netcat',),
#  (u'maintenance',),
#  (u'java', u'path', u'system'),
#  (u'c#', u'c++', u'java', u'python', u'strong-typing'),
#  (u'iphone', u'xcode'),
#  (u'php',),
#  (u'apache2', u'joomla', u'linux'),
#  (u'jquery',),
#  (u'.net', u'comm', u'mfc', u'midi'),
#  (u'css', u'data-uri'),
#  (u'https', u'ssl'),
#  (u'android', u'android-ndk', u'android-source'),
#  (u'ios', u'ios4.3', u'iphone', u'iphone-3gs', u'upgrade'),
#  (u'asp.net-mvc', u'design', u'modelstate', u'service-layer'),
#  (u'page-breaking', u'theorems'),
#  (u'testing', u'theory', u'unit-testing'),
#  (u'analysis', u'measure-theory', u'real-analysis'),
#  (u'emacs',),
#  (u'customization', u'firefox', u'keyboard-shortcuts', u'mac'),
#  (u'filenames', u'ntfs'),
#  (u'html',),
#  (u'oracle', u'plsql', u'reporting-services'),
#  (),
#  (u'annotations', u'powershell', u'tfs'),
#  (u'.net', u'c#', u'exception-handling', u'xml'),
#  (u'.net', u'winforms'),
#  (u'twitter', u'twitter-api'),
#  (u'backup', u'centos', u'cron', u'shell'),
#  (),
#  (u'javascript',),
#  (),
#  (u'exception-handling', u'java'),
#  (u'entity-framework',),
#  (u'eclipse', u'keyboard-shortcuts', u'run'),
#  (u'asp.net-mvc-3', u'javascript', u'mvc', u'security'),
#  (u'c#', u'isolatedstorage', u'session', u'silverlight'),
#  (),
#  (u'temporal', u'temporal-database', u'temporal-difference'),
#  (u'java', u'jsp', u'session-state'),
#  (u'facebook', u'wordpress'),
#  (u'javascript', u'javascript-events', u'prototypejs'),
#  (u'counters', u'loops'),
#  (u'mercurial', u'version-control'),
#  (u'encryption', u'python'),
#  (u'cmake', u'visual-studio'),
#  (u'internet-security', u'linux', u'security', u'ubuntu', u'ubuntu-10.04'),
#  (),
#  (u'axis2', u'java', u'ruby', u'savon', u'wsdl'),
#  (u'bash', u'ftp', u'iptables', u'linux'),
#  (u'application', u'launch-services', u'osx', u'osx-mountain-lion'),
#  (u'css', u'css3', u'pseudo-class', u'scrollbar', u'webkit'),
#  (u'effect', u'javascript', u'jquery', u'transition'),
#  (u'libssh',),
#  (),
#  (u'f#',),
#  (),
#  (u'jquery',),
#  (u'java',),
#  (u'file-upload', u'php', u'warnings'),
#  (u'c', u'gcc', u'pointers'),
#  (u'xslt',),
#  (u'c', u'matlab', u'mex', u'thread-safety'),
#  (u'jsp', u'struts-1'),
#  (u'calculus', u'functional-equations', u'inequality', u'limit'),
#  (),
#  (u'php',),
#  (u'centos', u'directory', u'disk', u'io', u'linux'),
#  (u'application', u'java-ee'),
#  (u'regex', u'sublimetext', u'sublimetext2', u'sublimetext3'),
#  (),
#  (u'graphiti', u'raphael'),
#  (),
#  (u'android',),
#  (u'permissions', u'security', u'sql-server-2008-r2'),
#  (u'cxf', u'jaxb', u'mule'),
#  (u'sql-server-ce',),
#  (u'calculus', u'general-topology', u'real-analysis'),
#  (u'jfreechart',),
#  (u'algorithm', u'binary-search', u'linear', u'search'),
#  (u'drupal', u'e-commerce', u'ubercart', u'virtuemart', u'wordpress'),
#  (u'c#', u'delete', u'post'),
#  (),
#  (u'c++', u'soundcard', u'xaudio2'),
#  (u'namespaces', u'postgresql'),
#  (u'iphone', u'memory-management', u'sdk', u'switch', u'view'),
#  (u'phonegap', u'ruby-on-rails'),
#  (u'algorithm', u'descendant', u'tree', u'trie'),
#  (u'.net', u'command-line', u'regex'),
#  (u'c++', u'directx', u'performance', u'shader'),
#  (u'organization', u'outlook'),
#  (u'http', u'request', u'ruby-on-rails', u'web-applications'),
#  (u'networking',),
#  (u'beautifier', u'php', u'php-beautifier'),
#  (u'mysql',),
#  (u'authentication', u'http', u'linux', u'proxy'),
#  (u'c', u'linux', u'operating-system', u'process', u'shell'),
#  (u'android', u'screen', u'size'),
#  (u'ruby-on-rails',),
#  (u'mysql', u'php'),
#  (u'c#', u'logging', u'nlog'),
#  (u'blackberry',),
#  (u'c#', u'namespaces', u'projects-and-solutions'),
#  (u'database', u'forms', u'jsp', u'mvc'),
#  (u'calculus', u'integration'),
#  (u'mechanize', u'ruby'),
#  (),
#  (u'char', u'microsoft'),
#  (u'facebook',),
#  (u'c#', u'linq-to-sql', u'sql', u'sql-server'),
#  (u'fft', u'frequency', u'math', u'matlab', u'signal-processing'),
#  (u'snow-leopard-server', u'upgrade'),
#  (u'azure-storage-tables', u'linq-to-sql'),
#  (u'basic-authentication', u'curl', u'http', u'php'),
#  (),
#  (u'bitmapdata', u'cropping', u'flex', u'resize', u'smooth'),
#  (u'android',),
#  (),
#  (u'calculus', u'real-analysis'),
#  (u'asp.net-ajax', u'asp.net-mvc', u'asp.net-mvc-3', u'jquery-ajax'),
#  (u'css', u'html', u'javascript', u'jquery', u'web'),
#  (u'acl', u'recovery', u'repair', u'windows-vista'),
#  (u'directx', u'gpu', u'image', u'java', u'rendering'),
#  (u'c#',),
#  (u'activity', u'android', u'layout'),
#  (u'authentication', u'iis', u'ntlm', u'reverse-proxy'),
#  (u'.net', u'c#', u'documentation', u'serialization'),
#  (),
#  (u'cobol', u'logical-operators'),
#  (u'asymptotics', u'notation'),
#  (u'c#', u'windows-phone-7'),
#  (),
#  (u'double', u'sql', u'sql-server', u'tsql'),
#  (u'jquery',),
#  (u'ironruby',),
#  (u'ef-code-first', u'entity-framework', u'seed'),
#  (u'command-line', u'windows-7'),
#  (u'development', u'event-receivers'),
#  (u'javascript', u'jquery', u'json', u'php'),
#  (u'cmake', u'command'),
#  (u'android', u'parsing', u'text', u'textview'),
#  (u'.net', u'hardware', u'serial-port'),
#  (u'books', u'excel'),
#  (u'dojo', u'grid', u'javascript', u'store'),
#  (u'android', u'eclipse'),
#  (u'google-analytics', u'google-analytics-api'),
#  (u'composer-php', u'packagist', u'php'),
#  (u'joomla',),
#  (),
#  (),
#  (),
#  (u'ios', u'iphone', u'objective-c', u'xcode'),
#  (u'class-design',
#   u'java',
#   u'reverse-engineering',
#   u'sequence-diagram',
#   u'uml'),
#  (u'join', u'left-join', u'ms-access', u'sql'),
#  (u'facebook', u'facebook-graph-api'),
#  (u'asp.net', u'asp.net-mvc'),
#  (u'android', u'database', u'nesting', u'sqlite'),
#  (),
#  (u'geospatial', u'spatial', u'sql-server', u'sql-server-ce'),
#  (u'architecture', u'exception-handling'),
#  (u'c++', u'python', u'swig'),
#  (),
#  (u'notation',),
#  (u'jsp', u'session', u'struts'),
#  (u'android', u'loaddata', u'webview'),
#  (u'java',),
#  (u'freebsd', u'ports'),
#  (u'joomla', u'menu', u'menuitem'),
#  (u'algorithm',),
#  (u'css',),
#  (u'gnuplot',),
#  (u'python',),
#  (u'ipad', u'iphone', u'objective-c'),
#  (u'android', u'java'),
#  (u'datetime', u'sql', u'sql-server', u'tsql'),
#  (u'compiler', u'javascript', u'parsing'),
#  (u'installation',),
#  (u'ajax', u'ruby-on-rails', u'validation'),
#  (u'diff', u'differences', u'tfs', u'tfs2008', u'tfs2010'),
#  (u'html5', u'jquery'),
#  (u'iadstsuserex', u'iphone', u'iphone-sdk-4.0'),
#  (u'c#', u'linq', u'linqpad'),
#  (u'jquery',),
#  (u'floating-point-precision', u'gsl', u'precision'),
#  (u'absolute-positioning', u'css', u'css-float', u'hotmail', u'html'),
#  (),
#  (u'c#', u'entity-framework', u'sqlite'),
#  (),
#  (u'c', u'c++', u'pointers'),
#  (u'python', u'python-ctypes', u'windows'),
#  (u'php', u'regex', u'string'),
#  (u'design', u'productivity', u'recommendations'),
#  (u'r',),
#  (u'calculation', u'calculator', u'equation'),
#  (u'jquery', u'json', u'zepto'),
#  (u'wpf', u'xaml'),
#  (u'php',),
#  (u'c#',
#   u'code-first',
#   u'code-first-migrations',
#   u'ef-code-first',
#   u'entity-framework-4'),
#  (u'installing', u'tikz-pgf'),
#  (u'date', u'php'),
#  (u'ios', u'ios4', u'iphone', u'objective-c', u'uitableview'),
#  (u'cygwin', u'git', u'git-tfs', u'tfs'),
#  (u'vb.net',),
#  (u'connectivity', u'remote-access', u'sql-server-2008-express'),
#  (u'javascript',),
#  (),
#  (u'ascii', u'java', u'word-processor'),
#  (u'git', u'grit', u'ruby'),
#  (),
#  (u'floating-point', u'ios', u'opengl-es', u'texture'),
#  (u'include', u'methods', u'module', u'ruby', u'static'),
#  (),
#  (u'android', u'live-wallpaper'),
#  (u'sharepoint',),
#  (u'matrix', u'python'),
#  (u'ajax', u'forms', u'jquery', u'jquery-plugins', u'post'),
#  (),
#  (u'ejb', u'jasper-reports', u'java'),
#  (u'debugging', u'eclipse', u'exception', u'java'),
#  (u'algorithm', u'kernel', u'linux', u'linux-device-driver'),
#  (u'colors', u'html', u'html5', u'javascript', u'mobile-safari'),
#  (u'java',),
#  (u'asp.net-mvc-3', u'formcollection', u'forms', u'jquery'),
#  (u'dataprovider', u'java', u'netbeans', u'testng'),
#  (u'jquery',),
#  (u'drivers', u'networking'),
#  (u'canvas', u'javascript'),
#  (u'facebook-timeline', u'news-feed', u'open-graph-beta', u'ticker'),
#  (u'.net', u'wcf', u'wcf-binding'),
#  (),
#  (u'file-server', u'kerberos', u'samba', u'share'),
#  (u'core-animation', u'ios'),
#  (u'asp.net', u'focus', u'textbox'),
#  (u'canvas', u'html', u'html5', u'html5-animation'),
#  (u'javascript', u'jquery'),
#  (u'css', u'jqtouch'),
#  (u'design-patterns', u'oop'),
#  (),
#  (u'django', u'django-multilingual', u'python'),
#  (u'connection', u'networking', u'vpn'),
#  (u'real-analysis',),
#  (u'nat-traversal', u'portforwarding', u'upnp'),
#  (u'jquery',),
#  (u'centos', u'iptables'),
#  (u'core-plot', u'ios', u'objective-c', u'touch'),
#  (u'c#', u'generic-interface', u'interface'),
#  (u'facebook-graph-api',),
#  (u'algebra', u'algorithm', u'c'),
#  (u'linux', u'networking', u'virtualization', u'xen'),
#  (u'asp.net',),
#  (u'geospatial', u'r'),
#  (u'sql-server-2008',),
#  (u'blackberry', u'daemon'),
#  (u'clojure',),
#  (u'ftp', u'html', u'http', u'internet'),
#  (u'svn', u'tortoisesvn'),
#  (u'jquery', u'selector'),
#  (u'regex',),
#  (u'concurrency', u'java', u'multithreading'),
#  (u'delete', u'osx-lion', u'recovery', u'time-machine'),
#  (u'android',),
#  (u'.net', u'c#', u'c#-3.0', u'c#-4.0', u'vb.net'),
#  (u'computer-science', u'video-lectures'),
#  (u'ios4', u'language', u'localization'),
#  (u'if-statement', u'nsbutton', u'objective-c', u'osx', u'xcode'),
#  (u'ruby-on-rails',),
#  (u'json', u'php'),
#  (),
#  (u'c#', u'data-binding', u'inkcanvas', u'wpf'),
#  (u'.net', u'sql', u'sql-server', u'sql-server-2005', u'sql-server-2008'),
#  (),
#  (u'dbunit', u'java', u'junit'),
#  (),
#  (u'headers', u'plugin-development', u'plugins'),
#  (u'ios', u'ios6'),
#  (),
#  (u'facebook-fql',
#   u'facebook-graph-api',
#   u'friend',
#   u'koala',
#   u'ruby-on-rails'),
#  (u'query', u'sitecore', u'user'),
#  (u'core-data',),
#  (u'bsd', u'netcat', u'security'),
#  (u'.net-4.0', u'c#', u'delegates', u'func'),
#  (u'arrays', u'hash', u'ruby'),
#  (),
#  (u'dot', u'graph-layout', u'graphviz', u'layout'),
#  (u'google-maps', u'google-maps-api-3', u'maps'),
#  (u'amazon-rds', u'mysql'),
#  (u'android', u'bitmap', u'channel', u'java', u'paint'),
#  (u'mysql', u'python'),
#  (),
#  (),
#  (),
#  (u'javascript',
#   u'ruby',
#   u'ruby-on-rails',
#   u'ruby-on-rails-3',
#   u'unobtrusive-javascript'),
#  (u'.net', u'development-environment', u'virtualization'),
#  (u'pages', u'wordpress.com'),
#  (u'calculus', u'integral'),
#  (u'robocopy', u'windows'),
#  (u'android', u'application', u'java', u'service'),
#  (u'absolute-path',
#   u'href',
#   u'internet-explorer-7',
#   u'jquery',
#   u'relative-path'),
#  (u'http-status-code-403', u'php', u'url-parameters'),
#  (u'dvcs', u'mercurial', u'version-control'),
#  (u'cocoa-touch', u'iphone', u'javascript', u'uiwebview', u'xml'),
#  (u'document-library', u'outlook'),
#  (),
#  (u'.net', u'c#', u'dll', u'scheduled-tasks', u'web-services'),
#  (u'blackberry', u'php', u'push-notification'),
#  (u'jquery', u'scroll'),
#  (),
#  (u'browser', u'xslt'),
#  (u'iphone',
#   u'network-protocols',
#   u'networking',
#   u'networkstream',
#   u'objective-c'),
#  (u'javascript', u'jquery', u'jquery-ui-resizable', u'resizable', u'resize'),
#  (u'windows-8', u'windows-8-upgrade', u'windows-xp'),
#  (u'apache', u'buffer', u'php'),
#  (u'csv', u'drupal', u'php'),
#  (u'ctypes', u'dll', u'dllexport', u'python'),
#  (u'probability', u'statistics'),
#  (u'asp.net', u'c#'),
#  (u'actionscript-3', u'flex'),
#  (u'ruby', u'soap', u'ssl'),
#  (u'backslash', u'boost', u'regex'),
#  (u'apache2', u'permissions', u'ubuntu'),
#  (u'dbref', u'mongodb', u'pymongo', u'query', u'reference'),
#  (),
#  (u'android', u'animation'),
#  (u'cocoa', u'objective-c', u'osx', u'pdfview', u'subclass'),
#  (u'arrays', u'java', u'rgb'),
#  (),
#  (u'html', u'javascript'),
#  (u'asp.net', u'c#', u'sql', u'xml'),
#  (u'git', u'patch'),
#  (),
#  (u'terminal', u'title', u'ubuntu'),
#  (u'database', u'database-design', u'ruby-on-rails-3', u'sql'),
#  (u'php', u'query', u'search', u'sql', u'weighted'),
#  (u'mfc', u'mfc-feature-pack'),
#  (u'jquery', u'quicksand'),
#  (u'asp.net-mvc',),
#  (u'guid', u'iqueryable', u'linq-to-sql'),
#  (u'c#', u'decimal', u'round', u'textbox'),
#  (u'node.js',),
#  (u'.net', u'c#', u'vsts2008'),
#  (u'document-classes', u'documentclass-writing'),
#  (),
#  (u'flowplayer', u'video'),
#  (u'apache2', u'html'),
#  (),
#  (u'ajax', u'dojo', u'inline-scripting'),
#  (u'css3', u'html5', u'jquery-mobile'),
#  (u'datagridview',
#   u'stored-procedures',
#   u'update',
#   u'vb.net',
#   u'visual-studio-2010'),
#  (u'iphone', u'linked-list', u'memory-allocation', u'objective-c'),
#  (u'mysql', u'sql'),
#  (u'asp.net', u'asp.net-mvc', u'asp.net-mvc-3'),
#  (u'canvas', u'jquery'),
#  (u'cisco-asa',),
#  (u'login', u'mysql'),
#  (u'php',),
#  (u'accordion', u'horizontal', u'javascript'),
#  (),
#  (u'css', u'css-transforms', u'css3', u'origin', u'webkit'),
#  (u'c++', u'load', u'shared-objects'),
#  (u'header', u'php', u'xml'),
#  (u'magento', u'magento-1.5', u'php'),
#  (u'bios', u'ssd', u'uefi', u'windows-8'),
#  (u'entity-framework-4', u'extension-methods', u'ninject'),
#  (u'asp.net', u'mvc'),
#  (),
#  (u'archive', u'configuration', u'cxf', u'java', u'war'),
#  (u'3d', u'java', u'java-3d'),
#  (u'.net', u'c#', u'entity-framework'),
#  (u'c#', u'deserialization', u'serialization', u'strongly-typed-dataset'),
#  (u'history', u'islam', u'russia'),
#  (u'classloader', u'cxf', u'tomcat', u'wss4j'),
#  (u'angularjs', u'javascript'),
#  (),
#  (u'xpath',),
#  (u'asp-classic', u'html5'),
#  (u'jsf', u'map'),
#  (u'bezier-curve', u'trigonometry'),
#  (u'mongodb-java',),
#  (u'http', u'tcp', u'webserver'),
#  (),
#  (u'android', u'audio', u'sdk', u'video'),
#  (u'icefaces', u'icefaces-1.8', u'java', u'jsf'),
#  (u'c', u'c++', u'extern'),
#  (u'arrays', u'computed-columns', u'numpy', u'python'),
#  (u'amazon-ec2', u'xen'),
#  (u'mysql', u'performance', u'performance-tuning', u'tuning'),
#  (u'html', u'jquery'),
#  (u'sectors', u'windows-7'),
#  (u'c++', u'openmp', u'random'),
#  (u'axes', u'geometry', u'matplotlib', u'subplot'),
#  (),
#  (u'interview', u'performance', u'practice-problems'),
#  (u'database', u'file-system', u'h2', u'playframework-2.0'),
#  (u'frameworks', u'gui'),
#  (u'ios', u'rotation', u'uiview', u'uiviewcontroller'),
#  (u'java', u'listener', u'swing'),
#  (u'c#', u'mobile', u'windows'),
#  (u'hp-pavilion',),
#  (u'locking', u'networking', u'windows'),
#  (),
#  (u'jquery',),
#  (u'powerbuilder',),
#  (u'c++', u'reference', u'rvalue'),
#  (u'scale', u'svg', u'text'),
#  (u'insert', u'mysql'),
#  (u'php', u'yii'),
#  (u'formula', u'microsoft-excel', u'vba'),
#  (u'connection', u'java', u'ssh'),
#  (u'filters', u'wp-mail'),
#  (u'gmail', u'imap', u'php'),
#  (u'backbone.js', u'coffeescript', u'jasmine', u'sinon', u'sprockets'),
#  (u'python',),
#  (),
#  (),
#  (u'encoding', u'php'),
#  (u'differential-equations',),
#  (u'android', u'bluetooth', u'connection'),
#  (u'parallelism',),
#  (u'combinatorics', u'dice', u'game-theory', u'probability'),
#  (u'drupal', u'drupal-7', u'panel', u'redirect', u'user'),
#  (u'command-line', u'settings', u'shortcut'),
#  (),
#  (u'b-tree', u'javascript', u'sorting'),
#  (u'database', u'dbms', u'java', u'ms-access'),
#  (u'conference', u'video', u'windows-xp'),
#  (u'clojure', u'macros'),
#  (u'date', u'mysql', u'sql'),
#  (u'.net', u'asp.net', u'asp.net-mvc', u'light', u'mvvm'),
#  (u'antivirus', u'malware', u'security', u'windows'),
#  (u'hotspot', u'wireless-access-point', u'wireless-networking'),
#  (u'64-bit', u'disk-utility', u'windows-7'),
#  (u'hash', u'password'),
#  (u'calculus', u'integral'),
#  (u'asp.net', u'communication', u'http', u'php'),
#  (u'iphone',),
#  (u'performance', u'windows-server-2003-r2'),
#  (),
#  (u'c#', u'nhibernate', u'orchardcms'),
#  (u'content', u'file', u'php'),
#  (u'memory', u'resource-monitor', u'windows'),
#  (),
#  (u'graph', u'openoffice-calc', u'plot', u'spreadsheet'),
#  (u'html',),
#  (),
#  (u'database', u'sql-server', u'visual-studio-2008'),
#  (u'coffeescript',
#   u'javascript',
#   u'ruby',
#   u'ruby-on-rails',
#   u'ruby-on-rails-3'),
#  (u'activexobject',
#   u'browser-extension',
#   u'firefox-addon',
#   u'google-chrome-extension'),
#  (u'customization',),
#  (u'iphone', u'openurl', u'passwords'),
#  (u'.net', u'c#', u'entity-framework', u'linq', u'linq-to-entities'),
#  (u'mercurial', u'sharepoint2010', u'synchronization', u'version-control'),
#  (u'backbone.js', u'coffeescript', u'ruby-on-rails-3.1'),
#  (u'ios', u'iphone', u'objective-c', u'swizzling'),
#  (),
#  (u'css', u'html'),
#  (),
#  (u'error', u'internet-explorer'),
#  (u'fedora', u'init-script', u'networking'),
#  (u'analysis', u'homework', u'real-analysis'),
#  (u'comments', u'functions'),
#  (u'amazon-s3', u'file-download', u'ruby-on-rails-2'),
#  (),
#  (u'cycle', u'jquery', u'slideshow'),
#  (u'autofocus', u'canon', u'focus'),
#  (u'java', u'security'),
#  (u'cocoa', u'iphone', u'sax', u'streaming', u'xml'),
#  (u'custom-controls', u'dtd', u'javascript', u'visual-studio', u'xml'),
#  (u'c#', u'xml'),
#  (u'opengl',),
#  (u'iphone',),
#  (u'calculus',
#   u'definite-integral',
#   u'improper-integrals',
#   u'real-analysis',
#   u'trigonometry'),
#  (u'.net', u'actionlink', u'asp.net', u'asp.net-mvc', u'c#'),
#  (u'directed-acyclic-graph',
#   u'ds.algorithms',
#   u'ds.data-structures',
#   u'graph-algorithms',
#   u'graph-theory'),
#  (u'java', u'spring'),
#  (u'architecture', u'multithreading', u'threadpool'),
#  (u'caching', u'php', u'twig'),
#  (u'hotspot', u'java', u'optimization'),
#  (u'cocoa', u'drag-and-drop', u'object-model', u'objective-c', u'pasteboard'),
#  (),
#  (u'fonts', u'putty', u'terminal', u'variable-width', u'windows'),
#  (u'boost', u'c++', u'visual-studio'),
#  (u'regex',),
#  (u'dictionary', u'list', u'performance', u'python', u'tuples'),
#  (u'ruby', u'windows', u'work-environment'),
#  (u'iphone',),
#  (u'php', u'preg-match'),
#  (u'jquery',),
#  (u'android', u'back-button', u'exit'),
#  (u'integration-testing', u'tdd', u'testing'),
#  (u'apache-karaf', u'apache-poi', u'osgi', u'osgi-bundle'),
#  (u'mvc', u'upgrade-issue', u'visual-studio-2010'),
#  (u'asp.net', u'authentication', u'sql-server'),
#  (u'c++', u'sspi', u'windows-mobile'),
#  (u'php',),
#  (u'api', u'ios', u'iphone', u'strip'),
#  (u'benchmarking', u'cloud', u'desktop-application', u'graphics', u'testing'),
#  (u'ios', u'ios5', u'iphone', u'xcode'),
#  (u'vb.net-2010',),
#  (u'categories', u'menus', u'php', u'thumbnails'),
#  (u'algebra-precalculus', u'geometry', u'terminology'),
#  (u'msmq', u'queue'),
#  (u'.net', u'c#', u'iis', u'vsts2010', u'wcf'),
#  (u'like-operator', u'sql'),
#  (u'configuration', u'ini', u'php'),
#  (u'android', u'database', u'java', u'json'),
#  (u'sharepoint', u'sharepoint2010'),
#  (u'c#', u'keyeventargs', u'wpf'),
#  (),
#  (),
#  (u'asp.net',
#   u'comparevalidator',
#   u'drop-down-menu',
#   u'requiredfieldvalidator',
#   u'visual-studio-2010'),
#  (u'clickable', u'div', u'events', u'jquery', u'propagation'),
#  (u'spacing', u'subfloats'),
#  (u'c#', u'graphics', u'panel', u'transparent'),
#  (u'c++',),
#  (u'configuration', u'linux', u'ubuntu'),
#  (u'eclipse', u'eclipse-plugin', u'scala'),
#  (u'ovi', u'pys60', u'python', u's60', u'symbian'),
#  (u'.net', u'garbage-collection', u'vb.net'),
#  (u'c#', u'functional-programming', u'performance', u'string'),
#  (u'ruby-on-rails',),
#  (u'cakephp', u'extract', u'php'),
#  (u'code-generation', u'css', u'internal'),
#  (u'android', u'java'),
#  (u'emacs', u'org-mode', u'tables'),
#  (),
#  (u'development-process', u'qa', u'quality'),
#  (u'class', u'css', u'internet-explorer'),
#  (u'android', u'bitmap', u'image-processing'),
#  (u'account', u'bash', u'creation'),
#  (u'comparison', u'java', u'mysql'),
#  (u'html', u'javascript', u'jquery'),
#  (u'iphone',),
#  (u'html', u'javascript', u'jquery', u'sso'),
#  (u'cc.complexity-theory', u'complexity-classes'),
#  (u'css', u'html', u'javascript'),
#  (u'backup', u'settings', u'vmware-esxi'),
#  (u'database', u'microsoft-access', u'oracle', u'sql'),
#  (u'audio', u'avaudioplayer', u'iphone', u'mixing'),
#  (u'linux-kernel', u'netlink', u'operating-system', u'sockets'),
#  (u'.net', u'javascript', u'typescript'),
#  (u'grub2', u'ubuntu'),
#  (u'db2', u'query', u'reindex', u'table'),
#  (u'apple', u'ios-simulator', u'ios5', u'ipad'),
#  (u'mysql', u'mysql-error-1054', u'vbulletin'),
#  (u'capistrano',),
#  (u'python', u'xpath', u'xslt'),
#  (u'perl', u'string'),
#  (),
#  (u'newline', u'php', u'strpos'),
#  (u'co-workers', u'jobs'),
#  (u'yii',),
#  (u'javascript',),
#  (),
#  (u'hibernate',),
#  (u'c#', u'log4net'),
#  (u'jquery',),
#  (u'ruby-on-rails', u'ruby-on-rails-3', u'shopify'),
#  (u'carbon', u'cocoa', u'osx'),
#  (u'flex3', u'flexbuilder'),
#  (u'javascript', u'jquery'),
#  (u'postgresql', u'security'),
#  (u'.net', u'.net-2.0', u'c#', u'linux', u'mono'),
#  (u'objective-c',),
#  (u'hammer', u'rtt', u'wireshark'),
#  (u'join', u'php', u'sql-server'),
#  (u'django', u'django-templates', u'image', u'python'),
#  (u'facebook-like',),
#  (u'internet-explorer-6',),
#  (u'c++', u'ide', u'linux', u'templates'),
#  (),
#  (),
#  (),
#  (u'c', u'environment-variables', u'visual-studio'),
#  (u'asp.net', u'c#', u'visual-studio-2010'),
#  (u'ajax', u'getjson', u'jquery', u'json'),
#  (u'r', u'time-series'),
#  (u'blend', u'expression-blend', u'silverlight'),
#  (),
#  (u'android', u'android-layout'),
#  (u'category-theory', u'examples-counterexamples', u'probability'),
#  (u'chmod', u'mac', u'osx', u'permissions'),
#  (u'full-text-search', u'performance', u'postgresql'),
#  (u'git', u'ssh'),
#  (u'defragment', u'windows-vista'),
#  (),
#  (),
#  (u'active-directory', u'new-account', u'password', u'user-accounts'),
#  (u'multithreading', u'python', u'queue', u'thread-safety'),
#  (u'cocoa-touch', u'ios', u'nsdate'),
#  (u'amazon', u'android', u'in-app-purchase'),
#  (u'c#', u'size', u'types'),
#  (u'dependency-injection', u'java', u'spring'),
#  (u'asp.net', u'asp.net-mvc'),
#  (),
#  (u'base-class', u'c++', u'derived-class', u'inheritance'),
#  (u'.net', u'activex', u'c#', u'winforms'),
#  (u'ios5', u'unity3d', u'xcode4'),
#  (),
#  (u'.net', u'couchbase', u'membase', u'memcached', u'ruby'),
#  (u'glteximage2d', u'opengl'),
#  (u'firefox-addon', u'javascript', u'right-click'),
#  (u'android', u'imageview'),
#  (u'database-design', u'database-schema', u'mongodb', u'ruby-on-rails-3'),
#  (u'formatting', u'gis', u'gpx', u'schema', u'xml'),
#  (),
#  (u'tfs', u'uninstall', u'visual-studio-2010'),
#  (u'abstract-algebra', u'hopf-algebras', u'quantum-groups'),
#  (u'database', u'filenames', u'image'),
#  (u'differential-equations',
#   u'power-series',
#   u'real-analysis',
#   u'special-functions'),
#  (u'mysql', u'python'),
#  (u'calculus', u'definite-integral', u'homework'),
#  (u'visual-studio',),
#  (u'composition', u'scala', u'traits'),
#  (),
#  (u'android', u'asp.net', u'iphone'),
#  (u'dom', u'get', u'html', u'index', u'jquery'),
#  (u'linux', u'scp', u'ssh', u'unix'),
#  (),
#  (u'facebook',
#   u'facebook-fql',
#   u'facebook-graph-api',
#   u'nokogiri',
#   u'ruby-on-rails'),
#  (u'objective-c',),
#  (u'c++', u'memory', u'pointers'),
#  (u'equivalent', u'jquery', u'prototypejs'),
#  (u'ios',),
#  (),
#  (u'folder', u'windows-xp'),
#  (u'deployment', u'java', u'packages'),
#  (),
#  (u'silverlight', u'wcf', u'wpf'),
#  (u'teradata',),
#  (),
#  (u'post',),
#  (u'cocoa', u'cocoa-touch', u'iphone'),
#  (u'.net', u'c#', u'iqueryable', u'linq', u'linq-to-entities'),
#  (u'action', u'ipad', u'objective-c', u'selector', u'uibutton'),
#  (u'django', u'model'),
#  (u'c++', u'qt'),
#  (u'comet', u'orbited', u'python', u'stomp', u'twisted'),
#  (u'c#', u'file-permissions', u'impersonation', u'windows-identity'),
#  (),
#  (u'java', u'stax', u'xml'),
#  (u'algorithm', u'directed-graph', u'graph-algorithm'),
#  (u'java', u'jvmti', u'multithreading'),
#  (u'cracking',
#   u'key-generator',
#   u'reverse-engineering',
#   u'software-protection'),
#  (u'c#', u'orchardcms'),
#  (u'c#', u'garbage-collection'),
#  (u'android', u'ios', u'qr-code'),
#  (u'c#',),
#  (u'jeditorpane', u'netbeans', u'platform', u'standalone', u'swing'),
#  (u'ajax', u'rest', u'ruby-on-rails'),
#  (u'books', u'ebook', u'ruby', u'ruby-on-rails'),
#  (),
#  (u'cocoa-touch', u'nsstring', u'objective-c', u'string-comparison'),
#  (u'div', u'event-handling', u'events', u'jquery-live'),
#  (u'cluster-computing', u'image', u'mysql', u'php'),
#  (u'c#', u'localization', u'usercontrols', u'winforms'),
#  (u'image-scaling', u'php'),
#  (u'c#', u'removing-whitespace', u'replace', u'string', u'whitespace'),
#  (),
#  (u'file-management', u'symbolic-link'),
#  (u'django', u'django-cms', u'internationalization'),
#  (),
#  (u'memory', u'python'),
#  (u'virtualization',),
#  (u'ios', u'ipad', u'iphone', u'objective-c'),
#  (u'javascript',),
#  (u'category-theory', u'logic', u'type-theory'),
#  (),
#  (),
#  (u'asp.net', u'entity-framework-4', u'linq-to-entities'),
#  (),
#  (u'.net', u'soap', u'wcf', u'web-services'),
#  (u'sql-server-2008',),
#  (u'ejb', u'java', u'spring'),
#  (u'flags', u'gcc', u'runtime'),
#  (u'emacs',),
#  (),
#  (u'mathematica', u'workbench'),
#  (u'numpy', u'python', u'windows'),
#  (u'core-data', u'iphone', u'nsmanagedobjectcontext', u'uitableview'),
#  (u'code-search-engine', u'html', u'javascript', u'search-engine'),
#  (u'.net', u'wpf'),
#  (u'adobe', u'flex', u'versioning'),
#  (u'ruby-on-rails',),
#  (u'arrays', u'php'),
#  (u'coffeescript',
#   u'node.js',
#   u'socket.io',
#   u'web-applications',
#   u'web-services'),
#  (u'directory', u'glob', u'mkdir', u'php'),
#  (u'html5', u'html5-video', u'video', u'video-processing', u'video-streaming'),
#  (u'.net', u'c#-4.0', u'crystal-reports', u'wpf'),
#  (u'mysql', u'php'),
#  (),
#  (u'appdomain', u'c#', u'marshalling', u'multithreading'),
#  (),
#  (u'attributes',
#   u'database-design',
#   u'maintainability',
#   u'pattern-recognition',
#   u'robustness'),
#  (),
#  (u'css', u'html5'),
#  (u'ascx', u'asp.net', u'c#', u'vb.net'),
#  (u'calculus', u'homework'),
#  (u'windows-7', u'windows-registry'),
#  (u'git',),
#  (u'batch', u'batch-file', u'compression', u'jpeg'),
#  (u'asp-classic', u'asp.net', u'sql', u'vbscript'),
#  (),
#  (u'search', u'segmentation-fault'),
#  (u'linear-algebra', u'matrices'),
#  (u'c++', u'winapi', u'windows'),
#  (u'canvas', u'drag', u'draggable', u'html5'),
#  (u'tikz-pgf',),
#  (u'ssh', u'windows'),
#  (u'artificial-intelligence', u'c#'),
#  (),
#  (u'iphone-sdk-4.0', u'objective-c'),
#  (),
#  (u'dd-wrt', u'networking', u'wireless-network'),
#  (),
#  (u'hostname', u'networking'),
#  (u'php',),
#  (u'android',),
#  (u'callback', u'forms', u'php', u'post', u'url'),
#  (u'git', u'svn'),
#  (u'php5', u'sql'),
#  (u'gpu', u'identification'),
#  (u'javascript', u'minify', u'squishit'),
#  (),
#  (u'.net', u'c#', u'http-headers', u'rest', u'wcf'),
#  (u'android',),
#  (u'grep', u'macvim', u'vim'),
#  (u'javascript',),
#  (u'asp.net', u'crystal-reports', u'vb.net'),
#  (u'composer-php', u'dependency-management', u'symfony2'),
#  (u'google-app-engine', u'google-fusion-tables', u'postgresql'),
#  (),
#  (u'jquery', u'jquery-mobile', u'mobile', u'web-interface'),
#  (u'amazon-cloudsearch', u'amazon-web-services', u'cloud', u'java'),
#  (u'file-sharing', u'file-transfer', u'windows'),
#  (u'rspec', u'ruby'),
#  (u'e-commerce', u'products', u'web-applications'),
#  (u'keymap', u'mac', u'osx', u'spaces'),
#  (),
#  (u'clang', u'gcc', u'xcode'),
#  (u'cookies', u'javascript'),
#  (u'bash', u'shell', u'unix'),
#  (u'css', u'css-selectors', u'html', u'last-child', u'stylesheet'),
#  (u'php', u'python'),
#  (u'cad', u'docking-station', u'laptop', u'multiple-monitors'),
#  (u'cropping', u'django', u'image'),
#  (u'php',),
#  (u'java',),
#  (u'java', u'multithreading'),
#  (u'css', u'internet-explorer-9', u'negative-margin'),
#  (u'c++', u'virtual', u'vtable'),
#  (u'events',),
#  (u'c++',),
#  (),
#  (),
#  (u'c++',),
#  (u'appliance', u'hardware', u'pdf', u'scanner', u'scanning'),
#  (u'mysql', u'php', u'sql'),
#  (u'arraylist', u'java'),
#  (u'devexpress', u'gridview', u'winforms'),
#  (u'adobe', u'digital-signature', u'pdf', u'signature'),
#  (u'redmine',),
#  (),
#  (),
#  (),
#  (u'binaryfiles', u'excel'),
#  (u'fluent-nhibernate', u'icriteria', u'nhibernate', u'nhibernate-mapping'),
#  (u'algorithm',),
#  (),
#  (u'fold', u'scala'),
#  (u'c#', u'sockets'),
#  (u'php',),
#  (u'ruby-on-rails',),
#  (u'dhcp-server', u'failover', u'isc-dhcp', u'nagios', u'status'),
#  (u'logging', u'nginx', u'performance'),
#  (u'optimization',),
#  (u'ios', u'ipad', u'iphone', u'twitter'),
#  (u'hibernate', u'hql', u'sql'),
#  (u'apache', u'encoding', u'mysql', u'php', u'utf-8'),
#  (u'spotify',),
#  (u'mysql', u'php', u'syntax-error', u'while-loop'),
#  (u'c#', u'regex'),
#  (),
#  (u'zend-search-lucene',),
#  (),
#  (u'distribution', u'mysql'),
#  (u'probability', u'probability-theory', u'statistics'),
#  (u'fonts', u'pgfplots'),
#  (u'append', u'html', u'javascript', u'jquery', u'nth-child'),
#  (u'mac', u'macosx', u'nginx'),
#  (u'perl', u'php'),
#  (u'java', u'java.util.concurrent', u'jboss7.x', u'multithreading'),
#  (),
#  (u'cryptography', u'encryption', u'pgp'),
#  (u'javascript', u'jquery'),
#  (u'aop', u'apache-camel', u'debugging', u'java', u'trace'),
#  (),
#  (u'junit4', u'spring-test', u'testing'),
#  (u'centos', u'dns', u'nameserver', u'whm'),
#  (u'vb.net', u'visual-studio-2010'),
#  (u'linguistics', u'tikz-qtree', u'trees'),
#  (u'ajax', u'base64', u'canvas', u'php'),
#  (u'iphone', u'iphone-sdk-3.0', u'objective-c'),
#  (u'codeigniter', u'image-gallery', u'jquery', u'php'),
#  (u'eager-loading', u'mongomapper', u'ruby'),
#  (u'c', u'quine'),
#  (u'php', u'security'),
#  (u'c++', u'stl', u'visual-studio'),
#  (u'c#', u'directx', u'screen-capture'),
#  (u'banach-spaces', u'hilbert-spaces', u'real-analysis'),
#  (u'backup', u'operating-systems'),
#  (u'boot', u'hp'),
#  (u'java',),
#  (u'phonegap',),
#  (u'doctrine', u'doctrine2', u'php'),
#  (u'localization', u'php', u'unicode'),
#  (u'c++',),
#  (u'cegui', u'ios', u'ogre', u'osx'),
#  (u'geolocation', u'ip-geolocation'),
#  (u'checkpoint',
#   u'cluster-computing',
#   u'distributed-computing',
#   u'java',
#   u'synchronization'),
#  (u'linq',),
#  (u'django', u'python'),
#  (u'java', u'methods'),
#  (u'css', u'menubar', u'wordpress'),
#  (u'ics', u'mime-types', u'php', u'upload'),
#  (u'asp.net-mvc', u'asp.net-mvc-3', u'ef-code-first', u'tdd', u'unit-testing'),
#  (u'c++', u'maintainability', u'optimization'),
#  (u'css', u'html', u'png', u'rendering', u'text-mode'),
#  (u'java', u'port', u'sockets'),
#  (u'html', u'php'),
#  (),
#  (u'c++', u'casting'),
#  (u'math-mode', u'math-operators', u'stack'),
#  (u'jquery', u'scroll', u'scrollto'),
#  (u'php',),
#  (u'cuda', u'gpu'),
#  (),
#  (u'r',),
#  (u'cucumber',),
#  (u'gsub', u'regex', u'ruby'),
#  (u'pde',),
#  (u'adobe',),
#  (),
#  (u'coldfusion-8', u'disabled-input', u'rtf'),
#  (),
#  (),
#  (u'agent',
#   u'algorithm',
#   u'artificial-intelligence',
#   u'first-order-logic',
#   u'logic'),
#  (u'algorithm', u'language-agnostic', u'particle-filter', u'probability'),
#  (u'asp.net', u'c#', u'regex'),
#  (),
#  (u'linux', u'xen'),
#  (),
#  (u'ajax', u'struts2'),
#  (u'android', u'android-widget'),
#  (u'canvas', u'java', u'swing'),
#  (u'activity', u'android', u'java'),
#  (u'ios', u'objective-c', u'sqlite'),
#  (u'amazon-ec2',),
#  (u'canvas', u'overlap', u'overlay', u'raphael'),
#  (u'sas',),
#  (u'comma', u'counter', u'javascript'),
#  (),
#  (u'email', u'forms', u'php', u'post', u'submit'),
#  (u'macports', u'osx', u'rsync', u'terminal'),
#  (u'regex',),
#  (u'c++', u'mouse', u'sdl', u'slider', u'trackbar'),
#  (u'database', u'persistence', u'workflow-foundation'),
#  (u'javascript', u'jquery', u'php'),
#  (u'android', u'animation', u'listview'),
#  (u'javascript', u'regex'),
#  (u'.htaccess', u'cron', u'cron-task', u'password-protection', u'wget'),
#  (u'javascript',),
#  (u'batch', u'batch-file', u'thunderbird'),
#  (u'boost-regex', u'c++', u'dll', u'icu'),
#  (),
#  (u'code-generation', u'java', u'latex'),
#  (u'aix', u'c', u'gcc'),
#  (u'asp.net', u'c#', u'caching'),
#  (u'baby-photos', u'outdoor', u'post-processing', u'workflow'),
#  (u'denyhosts', u'fail2ban', u'security', u'ubuntu-10.04'),
#  (u'c++', u'frequency-analysis', u'm4a', u'mp3'),
#  (u'asp.net',),
#  (u'css', u'html'),
#  (),
#  (u'html', u'html-parsing'),
#  (u'custom-build-step', u'setup-project', u'visual-studio-2008'),
#  (u'android',),
#  (u'ip', u'java', u'subnet'),
#  (),
#  (u'configuration', u'opengl', u'qt'),
#  (u'wpf', u'xbap'),
#  (u'ios', u'iphone', u'objective-c'),
#  (u'comments', u'standards', u'visual-studio-2008'),
#  (u'arrays', u'javascript', u'loops', u'variables'),
#  (u'c#',),
#  (u'bash', u'bash-scripting', u'sudo'),
#  (),
#  (u'f#', u'type-inference'),
#  (u'database-design', u'mysql', u'oracle', u'sql-server'),
#  (u'real-analysis',),
#  (u'arrays', u'date', u'php'),
#  (u'frameworks', u'mvc', u'php', u'symfony'),
#  (u'apache2', u'gzip', u'mod-rewrite'),
#  (u'api', u'cross-platform', u'rest'),
#  (u'.net', u'c#', u'saml', u'sso', u'xml'),
#  (),
#  (u'interface-builder', u'ios', u'iphone'),
#  (u'ace', u'c++'),
#  (u'algorithm', u'arrays', u'dynamic-programming', u'sub-arrays'),
#  (u'base', u'hotlinking', u'href', u'xml'),
#  (u'blogs', u'embed', u'javascript', u'joomla', u'joomla1.5'),
#  (u'javascript', u'youtube'),
#  (u'.htaccess', u'header', u'http', u'php'),
#  (u'coldfusion', u'forms', u'option', u'sql'),
#  (u'android', u'blackberry', u'iphone', u'smartphone', u'web-applications'),
#  (u'asp.net', u'updatepanel'),
#  (u'php',),
#  (u'.net', u'asp.net', u'treeview'),
#  (u'sql', u'vb.net'),
#  (),
#  (u'core-data', u'iphone'),
#  (u'binary', u'binding', u'ivalueconverter'),
#  (u'gps', u'iphone', u'javascript', u'web-applications'),
#  (u'windows-xp',),
#  (u'compression', u'gzip', u'linux'),
#  (u'android', u'android-images', u'android-imageview'),
#  (u'javascript',),
#  (u'entity-framework',
#   u'entity-framework-4',
#   u'sql',
#   u'sql-server',
#   u'sql-server-2008'),
#  (u'ilist', u'iqueryable', u'linq', u'select'),
#  (),
#  (u'mysql', u'python'),
#  (u'iis', u'iis7'),
#  (u'jquery', u'prototypejs'),
#  (u'tortoisegit',),
#  (u'wireless-networking', u'wps'),
#  (u'apache2', u'httpd.conf', u'linux', u'php', u'virtual-directory'),
#  (u'data-binding', u'pdo', u'php'),
#  (u'macports', u'osx', u'ruby', u'ruby-on-rails', u'rubygems'),
#  (u'html', u'jquery'),
#  (u'android', u'skype'),
#  (u'android',),
#  (u'c++',),
#  (),
#  (u'css', u'magento'),
#  (u'arrays', u'java', u'static'),
#  (u'c', u'gcc', u'performance'),
#  (u'browser', u'javascript', u'selected-text'),
#  (u'javascript', u'phonegap', u'scrollbar'),
#  (),
#  (u'jquery',),
#  (u'java-me', u'lwuit'),
#  (u'lotus-notes',),
#  (u'java', u'map', u'nullpointerexception'),
#  (u'silverlight', u'visual-studio-2010'),
#  (u'c++', u'destructor', u'sdl', u'tick'),
#  (u'python',),
#  (u'close', u'database-connection', u'destructor', u'java'),
#  (u'integer', u'python', u'random'),
#  (),
#  (u'core-data', u'ios'),
#  (u'mtu', u'tp-link', u'wireless-router'),
#  (u'linux',),
#  (u'block', u'prestashop'),
#  (u'c++', u'c++11', u'initializer-list', u'unions'),
#  (u'android', u'eclipse', u'xml'),
#  (u'c#', u'mongodb'),
#  ...]

# %%
#Reference for encoding the list to UTF-8 : https://stackoverflow.com/questions/27714750/encoding-a-list-of-tuples-with-python
decoded = [[word.encode("utf8") for word in sets] for sets in all_labels]

# %%
#Print the decoded list
decoded
# Out:
# [['file-upload', 'image-processing', 'mime-types', 'php', 'upload'],
#  ['firefox'],
#  ['c#', 'encoding', 'url'],
#  ['api', 'file-get-contents', 'php'],
#  ['active-directory', 'jmeter', 'proxy'],
#  ['core-plot'],
#  ['asp.net', 'c#', 'windows-phone-7'],
#  ['.net', 'code-generation', 'javascript'],
#  ['calls', 'parameters', 'procedure', 'sql', 'variables'],
#  ['.net', 'obfuscation', 'reflector'],
#  ['mdaemon', 'migration', 'postfix'],
#  ['machine-learning', 'matlab', 'r'],
#  ['algorithm', 'language-agnostic', 'random'],
#  ['documentation', 'expl3', 'latex3'],
#  ['windows-7'],
#  ['conventions', 'php', 'url-routing'],
#  [],
#  [],
#  ['code-generation', 'javascript', 'minify', 'playframework'],
#  ['hash', 'multidimensional-array', 'php', 'simplexml-load-string', 'xml'],
#  ['cancer', 'healthcare', 'medical-science'],
#  ['.net', 'c#', 'linq'],
#  [],
#  ['iis'],
#  ['c#'],
#  ['haskell'],
#  ['gnu', 'makefile', 'visual-studio'],
#  ['html', 'line-breaks', 'semantic'],
#  ['bounds-checker', 'c++', 'gcc', 'stl'],
#  [],
#  ['asp.net-mvc-4', 'asp.net-optimization', 'bundle', 'css', 'jquery-ui'],
#  ['c#', 'entity-framework-4'],
#  [],
#  ['apk', 'monodroid'],
#  ['mvvm', 'wpf'],
#  ['calculus', 'homework', 'polar-coordinates'],
#  ['netcat'],
#  ['maintenance'],
#  ['java', 'path', 'system'],
#  ['c#', 'c++', 'java', 'python', 'strong-typing'],
#  ['iphone', 'xcode'],
#  ['php'],
#  ['apache2', 'joomla', 'linux'],
#  ['jquery'],
#  ['.net', 'comm', 'mfc', 'midi'],
#  ['css', 'data-uri'],
#  ['https', 'ssl'],
#  ['android', 'android-ndk', 'android-source'],
#  ['ios', 'ios4.3', 'iphone', 'iphone-3gs', 'upgrade'],
#  ['asp.net-mvc', 'design', 'modelstate', 'service-layer'],
#  ['page-breaking', 'theorems'],
#  ['testing', 'theory', 'unit-testing'],
#  ['analysis', 'measure-theory', 'real-analysis'],
#  ['emacs'],
#  ['customization', 'firefox', 'keyboard-shortcuts', 'mac'],
#  ['filenames', 'ntfs'],
#  ['html'],
#  ['oracle', 'plsql', 'reporting-services'],
#  [],
#  ['annotations', 'powershell', 'tfs'],
#  ['.net', 'c#', 'exception-handling', 'xml'],
#  ['.net', 'winforms'],
#  ['twitter', 'twitter-api'],
#  ['backup', 'centos', 'cron', 'shell'],
#  [],
#  ['javascript'],
#  [],
#  ['exception-handling', 'java'],
#  ['entity-framework'],
#  ['eclipse', 'keyboard-shortcuts', 'run'],
#  ['asp.net-mvc-3', 'javascript', 'mvc', 'security'],
#  ['c#', 'isolatedstorage', 'session', 'silverlight'],
#  [],
#  ['temporal', 'temporal-database', 'temporal-difference'],
#  ['java', 'jsp', 'session-state'],
#  ['facebook', 'wordpress'],
#  ['javascript', 'javascript-events', 'prototypejs'],
#  ['counters', 'loops'],
#  ['mercurial', 'version-control'],
#  ['encryption', 'python'],
#  ['cmake', 'visual-studio'],
#  ['internet-security', 'linux', 'security', 'ubuntu', 'ubuntu-10.04'],
#  [],
#  ['axis2', 'java', 'ruby', 'savon', 'wsdl'],
#  ['bash', 'ftp', 'iptables', 'linux'],
#  ['application', 'launch-services', 'osx', 'osx-mountain-lion'],
#  ['css', 'css3', 'pseudo-class', 'scrollbar', 'webkit'],
#  ['effect', 'javascript', 'jquery', 'transition'],
#  ['libssh'],
#  [],
#  ['f#'],
#  [],
#  ['jquery'],
#  ['java'],
#  ['file-upload', 'php', 'warnings'],
#  ['c', 'gcc', 'pointers'],
#  ['xslt'],
#  ['c', 'matlab', 'mex', 'thread-safety'],
#  ['jsp', 'struts-1'],
#  ['calculus', 'functional-equations', 'inequality', 'limit'],
#  [],
#  ['php'],
#  ['centos', 'directory', 'disk', 'io', 'linux'],
#  ['application', 'java-ee'],
#  ['regex', 'sublimetext', 'sublimetext2', 'sublimetext3'],
#  [],
#  ['graphiti', 'raphael'],
#  [],
#  ['android'],
#  ['permissions', 'security', 'sql-server-2008-r2'],
#  ['cxf', 'jaxb', 'mule'],
#  ['sql-server-ce'],
#  ['calculus', 'general-topology', 'real-analysis'],
#  ['jfreechart'],
#  ['algorithm', 'binary-search', 'linear', 'search'],
#  ['drupal', 'e-commerce', 'ubercart', 'virtuemart', 'wordpress'],
#  ['c#', 'delete', 'post'],
#  [],
#  ['c++', 'soundcard', 'xaudio2'],
#  ['namespaces', 'postgresql'],
#  ['iphone', 'memory-management', 'sdk', 'switch', 'view'],
#  ['phonegap', 'ruby-on-rails'],
#  ['algorithm', 'descendant', 'tree', 'trie'],
#  ['.net', 'command-line', 'regex'],
#  ['c++', 'directx', 'performance', 'shader'],
#  ['organization', 'outlook'],
#  ['http', 'request', 'ruby-on-rails', 'web-applications'],
#  ['networking'],
#  ['beautifier', 'php', 'php-beautifier'],
#  ['mysql'],
#  ['authentication', 'http', 'linux', 'proxy'],
#  ['c', 'linux', 'operating-system', 'process', 'shell'],
#  ['android', 'screen', 'size'],
#  ['ruby-on-rails'],
#  ['mysql', 'php'],
#  ['c#', 'logging', 'nlog'],
#  ['blackberry'],
#  ['c#', 'namespaces', 'projects-and-solutions'],
#  ['database', 'forms', 'jsp', 'mvc'],
#  ['calculus', 'integration'],
#  ['mechanize', 'ruby'],
#  [],
#  ['char', 'microsoft'],
#  ['facebook'],
#  ['c#', 'linq-to-sql', 'sql', 'sql-server'],
#  ['fft', 'frequency', 'math', 'matlab', 'signal-processing'],
#  ['snow-leopard-server', 'upgrade'],
#  ['azure-storage-tables', 'linq-to-sql'],
#  ['basic-authentication', 'curl', 'http', 'php'],
#  [],
#  ['bitmapdata', 'cropping', 'flex', 'resize', 'smooth'],
#  ['android'],
#  [],
#  ['calculus', 'real-analysis'],
#  ['asp.net-ajax', 'asp.net-mvc', 'asp.net-mvc-3', 'jquery-ajax'],
#  ['css', 'html', 'javascript', 'jquery', 'web'],
#  ['acl', 'recovery', 'repair', 'windows-vista'],
#  ['directx', 'gpu', 'image', 'java', 'rendering'],
#  ['c#'],
#  ['activity', 'android', 'layout'],
#  ['authentication', 'iis', 'ntlm', 'reverse-proxy'],
#  ['.net', 'c#', 'documentation', 'serialization'],
#  [],
#  ['cobol', 'logical-operators'],
#  ['asymptotics', 'notation'],
#  ['c#', 'windows-phone-7'],
#  [],
#  ['double', 'sql', 'sql-server', 'tsql'],
#  ['jquery'],
#  ['ironruby'],
#  ['ef-code-first', 'entity-framework', 'seed'],
#  ['command-line', 'windows-7'],
#  ['development', 'event-receivers'],
#  ['javascript', 'jquery', 'json', 'php'],
#  ['cmake', 'command'],
#  ['android', 'parsing', 'text', 'textview'],
#  ['.net', 'hardware', 'serial-port'],
#  ['books', 'excel'],
#  ['dojo', 'grid', 'javascript', 'store'],
#  ['android', 'eclipse'],
#  ['google-analytics', 'google-analytics-api'],
#  ['composer-php', 'packagist', 'php'],
#  ['joomla'],
#  [],
#  [],
#  [],
#  ['ios', 'iphone', 'objective-c', 'xcode'],
#  ['class-design', 'java', 'reverse-engineering', 'sequence-diagram', 'uml'],
#  ['join', 'left-join', 'ms-access', 'sql'],
#  ['facebook', 'facebook-graph-api'],
#  ['asp.net', 'asp.net-mvc'],
#  ['android', 'database', 'nesting', 'sqlite'],
#  [],
#  ['geospatial', 'spatial', 'sql-server', 'sql-server-ce'],
#  ['architecture', 'exception-handling'],
#  ['c++', 'python', 'swig'],
#  [],
#  ['notation'],
#  ['jsp', 'session', 'struts'],
#  ['android', 'loaddata', 'webview'],
#  ['java'],
#  ['freebsd', 'ports'],
#  ['joomla', 'menu', 'menuitem'],
#  ['algorithm'],
#  ['css'],
#  ['gnuplot'],
#  ['python'],
#  ['ipad', 'iphone', 'objective-c'],
#  ['android', 'java'],
#  ['datetime', 'sql', 'sql-server', 'tsql'],
#  ['compiler', 'javascript', 'parsing'],
#  ['installation'],
#  ['ajax', 'ruby-on-rails', 'validation'],
#  ['diff', 'differences', 'tfs', 'tfs2008', 'tfs2010'],
#  ['html5', 'jquery'],
#  ['iadstsuserex', 'iphone', 'iphone-sdk-4.0'],
#  ['c#', 'linq', 'linqpad'],
#  ['jquery'],
#  ['floating-point-precision', 'gsl', 'precision'],
#  ['absolute-positioning', 'css', 'css-float', 'hotmail', 'html'],
#  [],
#  ['c#', 'entity-framework', 'sqlite'],
#  [],
#  ['c', 'c++', 'pointers'],
#  ['python', 'python-ctypes', 'windows'],
#  ['php', 'regex', 'string'],
#  ['design', 'productivity', 'recommendations'],
#  ['r'],
#  ['calculation', 'calculator', 'equation'],
#  ['jquery', 'json', 'zepto'],
#  ['wpf', 'xaml'],
#  ['php'],
#  ['c#',
#   'code-first',
#   'code-first-migrations',
#   'ef-code-first',
#   'entity-framework-4'],
#  ['installing', 'tikz-pgf'],
#  ['date', 'php'],
#  ['ios', 'ios4', 'iphone', 'objective-c', 'uitableview'],
#  ['cygwin', 'git', 'git-tfs', 'tfs'],
#  ['vb.net'],
#  ['connectivity', 'remote-access', 'sql-server-2008-express'],
#  ['javascript'],
#  [],
#  ['ascii', 'java', 'word-processor'],
#  ['git', 'grit', 'ruby'],
#  [],
#  ['floating-point', 'ios', 'opengl-es', 'texture'],
#  ['include', 'methods', 'module', 'ruby', 'static'],
#  [],
#  ['android', 'live-wallpaper'],
#  ['sharepoint'],
#  ['matrix', 'python'],
#  ['ajax', 'forms', 'jquery', 'jquery-plugins', 'post'],
#  [],
#  ['ejb', 'jasper-reports', 'java'],
#  ['debugging', 'eclipse', 'exception', 'java'],
#  ['algorithm', 'kernel', 'linux', 'linux-device-driver'],
#  ['colors', 'html', 'html5', 'javascript', 'mobile-safari'],
#  ['java'],
#  ['asp.net-mvc-3', 'formcollection', 'forms', 'jquery'],
#  ['dataprovider', 'java', 'netbeans', 'testng'],
#  ['jquery'],
#  ['drivers', 'networking'],
#  ['canvas', 'javascript'],
#  ['facebook-timeline', 'news-feed', 'open-graph-beta', 'ticker'],
#  ['.net', 'wcf', 'wcf-binding'],
#  [],
#  ['file-server', 'kerberos', 'samba', 'share'],
#  ['core-animation', 'ios'],
#  ['asp.net', 'focus', 'textbox'],
#  ['canvas', 'html', 'html5', 'html5-animation'],
#  ['javascript', 'jquery'],
#  ['css', 'jqtouch'],
#  ['design-patterns', 'oop'],
#  [],
#  ['django', 'django-multilingual', 'python'],
#  ['connection', 'networking', 'vpn'],
#  ['real-analysis'],
#  ['nat-traversal', 'portforwarding', 'upnp'],
#  ['jquery'],
#  ['centos', 'iptables'],
#  ['core-plot', 'ios', 'objective-c', 'touch'],
#  ['c#', 'generic-interface', 'interface'],
#  ['facebook-graph-api'],
#  ['algebra', 'algorithm', 'c'],
#  ['linux', 'networking', 'virtualization', 'xen'],
#  ['asp.net'],
#  ['geospatial', 'r'],
#  ['sql-server-2008'],
#  ['blackberry', 'daemon'],
#  ['clojure'],
#  ['ftp', 'html', 'http', 'internet'],
#  ['svn', 'tortoisesvn'],
#  ['jquery', 'selector'],
#  ['regex'],
#  ['concurrency', 'java', 'multithreading'],
#  ['delete', 'osx-lion', 'recovery', 'time-machine'],
#  ['android'],
#  ['.net', 'c#', 'c#-3.0', 'c#-4.0', 'vb.net'],
#  ['computer-science', 'video-lectures'],
#  ['ios4', 'language', 'localization'],
#  ['if-statement', 'nsbutton', 'objective-c', 'osx', 'xcode'],
#  ['ruby-on-rails'],
#  ['json', 'php'],
#  [],
#  ['c#', 'data-binding', 'inkcanvas', 'wpf'],
#  ['.net', 'sql', 'sql-server', 'sql-server-2005', 'sql-server-2008'],
#  [],
#  ['dbunit', 'java', 'junit'],
#  [],
#  ['headers', 'plugin-development', 'plugins'],
#  ['ios', 'ios6'],
#  [],
#  ['facebook-fql', 'facebook-graph-api', 'friend', 'koala', 'ruby-on-rails'],
#  ['query', 'sitecore', 'user'],
#  ['core-data'],
#  ['bsd', 'netcat', 'security'],
#  ['.net-4.0', 'c#', 'delegates', 'func'],
#  ['arrays', 'hash', 'ruby'],
#  [],
#  ['dot', 'graph-layout', 'graphviz', 'layout'],
#  ['google-maps', 'google-maps-api-3', 'maps'],
#  ['amazon-rds', 'mysql'],
#  ['android', 'bitmap', 'channel', 'java', 'paint'],
#  ['mysql', 'python'],
#  [],
#  [],
#  [],
#  ['javascript',
#   'ruby',
#   'ruby-on-rails',
#   'ruby-on-rails-3',
#   'unobtrusive-javascript'],
#  ['.net', 'development-environment', 'virtualization'],
#  ['pages', 'wordpress.com'],
#  ['calculus', 'integral'],
#  ['robocopy', 'windows'],
#  ['android', 'application', 'java', 'service'],
#  ['absolute-path', 'href', 'internet-explorer-7', 'jquery', 'relative-path'],
#  ['http-status-code-403', 'php', 'url-parameters'],
#  ['dvcs', 'mercurial', 'version-control'],
#  ['cocoa-touch', 'iphone', 'javascript', 'uiwebview', 'xml'],
#  ['document-library', 'outlook'],
#  [],
#  ['.net', 'c#', 'dll', 'scheduled-tasks', 'web-services'],
#  ['blackberry', 'php', 'push-notification'],
#  ['jquery', 'scroll'],
#  [],
#  ['browser', 'xslt'],
#  ['iphone', 'network-protocols', 'networking', 'networkstream', 'objective-c'],
#  ['javascript', 'jquery', 'jquery-ui-resizable', 'resizable', 'resize'],
#  ['windows-8', 'windows-8-upgrade', 'windows-xp'],
#  ['apache', 'buffer', 'php'],
#  ['csv', 'drupal', 'php'],
#  ['ctypes', 'dll', 'dllexport', 'python'],
#  ['probability', 'statistics'],
#  ['asp.net', 'c#'],
#  ['actionscript-3', 'flex'],
#  ['ruby', 'soap', 'ssl'],
#  ['backslash', 'boost', 'regex'],
#  ['apache2', 'permissions', 'ubuntu'],
#  ['dbref', 'mongodb', 'pymongo', 'query', 'reference'],
#  [],
#  ['android', 'animation'],
#  ['cocoa', 'objective-c', 'osx', 'pdfview', 'subclass'],
#  ['arrays', 'java', 'rgb'],
#  [],
#  ['html', 'javascript'],
#  ['asp.net', 'c#', 'sql', 'xml'],
#  ['git', 'patch'],
#  [],
#  ['terminal', 'title', 'ubuntu'],
#  ['database', 'database-design', 'ruby-on-rails-3', 'sql'],
#  ['php', 'query', 'search', 'sql', 'weighted'],
#  ['mfc', 'mfc-feature-pack'],
#  ['jquery', 'quicksand'],
#  ['asp.net-mvc'],
#  ['guid', 'iqueryable', 'linq-to-sql'],
#  ['c#', 'decimal', 'round', 'textbox'],
#  ['node.js'],
#  ['.net', 'c#', 'vsts2008'],
#  ['document-classes', 'documentclass-writing'],
#  [],
#  ['flowplayer', 'video'],
#  ['apache2', 'html'],
#  [],
#  ['ajax', 'dojo', 'inline-scripting'],
#  ['css3', 'html5', 'jquery-mobile'],
#  ['datagridview',
#   'stored-procedures',
#   'update',
#   'vb.net',
#   'visual-studio-2010'],
#  ['iphone', 'linked-list', 'memory-allocation', 'objective-c'],
#  ['mysql', 'sql'],
#  ['asp.net', 'asp.net-mvc', 'asp.net-mvc-3'],
#  ['canvas', 'jquery'],
#  ['cisco-asa'],
#  ['login', 'mysql'],
#  ['php'],
#  ['accordion', 'horizontal', 'javascript'],
#  [],
#  ['css', 'css-transforms', 'css3', 'origin', 'webkit'],
#  ['c++', 'load', 'shared-objects'],
#  ['header', 'php', 'xml'],
#  ['magento', 'magento-1.5', 'php'],
#  ['bios', 'ssd', 'uefi', 'windows-8'],
#  ['entity-framework-4', 'extension-methods', 'ninject'],
#  ['asp.net', 'mvc'],
#  [],
#  ['archive', 'configuration', 'cxf', 'java', 'war'],
#  ['3d', 'java', 'java-3d'],
#  ['.net', 'c#', 'entity-framework'],
#  ['c#', 'deserialization', 'serialization', 'strongly-typed-dataset'],
#  ['history', 'islam', 'russia'],
#  ['classloader', 'cxf', 'tomcat', 'wss4j'],
#  ['angularjs', 'javascript'],
#  [],
#  ['xpath'],
#  ['asp-classic', 'html5'],
#  ['jsf', 'map'],
#  ['bezier-curve', 'trigonometry'],
#  ['mongodb-java'],
#  ['http', 'tcp', 'webserver'],
#  [],
#  ['android', 'audio', 'sdk', 'video'],
#  ['icefaces', 'icefaces-1.8', 'java', 'jsf'],
#  ['c', 'c++', 'extern'],
#  ['arrays', 'computed-columns', 'numpy', 'python'],
#  ['amazon-ec2', 'xen'],
#  ['mysql', 'performance', 'performance-tuning', 'tuning'],
#  ['html', 'jquery'],
#  ['sectors', 'windows-7'],
#  ['c++', 'openmp', 'random'],
#  ['axes', 'geometry', 'matplotlib', 'subplot'],
#  [],
#  ['interview', 'performance', 'practice-problems'],
#  ['database', 'file-system', 'h2', 'playframework-2.0'],
#  ['frameworks', 'gui'],
#  ['ios', 'rotation', 'uiview', 'uiviewcontroller'],
#  ['java', 'listener', 'swing'],
#  ['c#', 'mobile', 'windows'],
#  ['hp-pavilion'],
#  ['locking', 'networking', 'windows'],
#  [],
#  ['jquery'],
#  ['powerbuilder'],
#  ['c++', 'reference', 'rvalue'],
#  ['scale', 'svg', 'text'],
#  ['insert', 'mysql'],
#  ['php', 'yii'],
#  ['formula', 'microsoft-excel', 'vba'],
#  ['connection', 'java', 'ssh'],
#  ['filters', 'wp-mail'],
#  ['gmail', 'imap', 'php'],
#  ['backbone.js', 'coffeescript', 'jasmine', 'sinon', 'sprockets'],
#  ['python'],
#  [],
#  [],
#  ['encoding', 'php'],
#  ['differential-equations'],
#  ['android', 'bluetooth', 'connection'],
#  ['parallelism'],
#  ['combinatorics', 'dice', 'game-theory', 'probability'],
#  ['drupal', 'drupal-7', 'panel', 'redirect', 'user'],
#  ['command-line', 'settings', 'shortcut'],
#  [],
#  ['b-tree', 'javascript', 'sorting'],
#  ['database', 'dbms', 'java', 'ms-access'],
#  ['conference', 'video', 'windows-xp'],
#  ['clojure', 'macros'],
#  ['date', 'mysql', 'sql'],
#  ['.net', 'asp.net', 'asp.net-mvc', 'light', 'mvvm'],
#  ['antivirus', 'malware', 'security', 'windows'],
#  ['hotspot', 'wireless-access-point', 'wireless-networking'],
#  ['64-bit', 'disk-utility', 'windows-7'],
#  ['hash', 'password'],
#  ['calculus', 'integral'],
#  ['asp.net', 'communication', 'http', 'php'],
#  ['iphone'],
#  ['performance', 'windows-server-2003-r2'],
#  [],
#  ['c#', 'nhibernate', 'orchardcms'],
#  ['content', 'file', 'php'],
#  ['memory', 'resource-monitor', 'windows'],
#  [],
#  ['graph', 'openoffice-calc', 'plot', 'spreadsheet'],
#  ['html'],
#  [],
#  ['database', 'sql-server', 'visual-studio-2008'],
#  ['coffeescript', 'javascript', 'ruby', 'ruby-on-rails', 'ruby-on-rails-3'],
#  ['activexobject',
#   'browser-extension',
#   'firefox-addon',
#   'google-chrome-extension'],
#  ['customization'],
#  ['iphone', 'openurl', 'passwords'],
#  ['.net', 'c#', 'entity-framework', 'linq', 'linq-to-entities'],
#  ['mercurial', 'sharepoint2010', 'synchronization', 'version-control'],
#  ['backbone.js', 'coffeescript', 'ruby-on-rails-3.1'],
#  ['ios', 'iphone', 'objective-c', 'swizzling'],
#  [],
#  ['css', 'html'],
#  [],
#  ['error', 'internet-explorer'],
#  ['fedora', 'init-script', 'networking'],
#  ['analysis', 'homework', 'real-analysis'],
#  ['comments', 'functions'],
#  ['amazon-s3', 'file-download', 'ruby-on-rails-2'],
#  [],
#  ['cycle', 'jquery', 'slideshow'],
#  ['autofocus', 'canon', 'focus'],
#  ['java', 'security'],
#  ['cocoa', 'iphone', 'sax', 'streaming', 'xml'],
#  ['custom-controls', 'dtd', 'javascript', 'visual-studio', 'xml'],
#  ['c#', 'xml'],
#  ['opengl'],
#  ['iphone'],
#  ['calculus',
#   'definite-integral',
#   'improper-integrals',
#   'real-analysis',
#   'trigonometry'],
#  ['.net', 'actionlink', 'asp.net', 'asp.net-mvc', 'c#'],
#  ['directed-acyclic-graph',
#   'ds.algorithms',
#   'ds.data-structures',
#   'graph-algorithms',
#   'graph-theory'],
#  ['java', 'spring'],
#  ['architecture', 'multithreading', 'threadpool'],
#  ['caching', 'php', 'twig'],
#  ['hotspot', 'java', 'optimization'],
#  ['cocoa', 'drag-and-drop', 'object-model', 'objective-c', 'pasteboard'],
#  [],
#  ['fonts', 'putty', 'terminal', 'variable-width', 'windows'],
#  ['boost', 'c++', 'visual-studio'],
#  ['regex'],
#  ['dictionary', 'list', 'performance', 'python', 'tuples'],
#  ['ruby', 'windows', 'work-environment'],
#  ['iphone'],
#  ['php', 'preg-match'],
#  ['jquery'],
#  ['android', 'back-button', 'exit'],
#  ['integration-testing', 'tdd', 'testing'],
#  ['apache-karaf', 'apache-poi', 'osgi', 'osgi-bundle'],
#  ['mvc', 'upgrade-issue', 'visual-studio-2010'],
#  ['asp.net', 'authentication', 'sql-server'],
#  ['c++', 'sspi', 'windows-mobile'],
#  ['php'],
#  ['api', 'ios', 'iphone', 'strip'],
#  ['benchmarking', 'cloud', 'desktop-application', 'graphics', 'testing'],
#  ['ios', 'ios5', 'iphone', 'xcode'],
#  ['vb.net-2010'],
#  ['categories', 'menus', 'php', 'thumbnails'],
#  ['algebra-precalculus', 'geometry', 'terminology'],
#  ['msmq', 'queue'],
#  ['.net', 'c#', 'iis', 'vsts2010', 'wcf'],
#  ['like-operator', 'sql'],
#  ['configuration', 'ini', 'php'],
#  ['android', 'database', 'java', 'json'],
#  ['sharepoint', 'sharepoint2010'],
#  ['c#', 'keyeventargs', 'wpf'],
#  [],
#  [],
#  ['asp.net',
#   'comparevalidator',
#   'drop-down-menu',
#   'requiredfieldvalidator',
#   'visual-studio-2010'],
#  ['clickable', 'div', 'events', 'jquery', 'propagation'],
#  ['spacing', 'subfloats'],
#  ['c#', 'graphics', 'panel', 'transparent'],
#  ['c++'],
#  ['configuration', 'linux', 'ubuntu'],
#  ['eclipse', 'eclipse-plugin', 'scala'],
#  ['ovi', 'pys60', 'python', 's60', 'symbian'],
#  ['.net', 'garbage-collection', 'vb.net'],
#  ['c#', 'functional-programming', 'performance', 'string'],
#  ['ruby-on-rails'],
#  ['cakephp', 'extract', 'php'],
#  ['code-generation', 'css', 'internal'],
#  ['android', 'java'],
#  ['emacs', 'org-mode', 'tables'],
#  [],
#  ['development-process', 'qa', 'quality'],
#  ['class', 'css', 'internet-explorer'],
#  ['android', 'bitmap', 'image-processing'],
#  ['account', 'bash', 'creation'],
#  ['comparison', 'java', 'mysql'],
#  ['html', 'javascript', 'jquery'],
#  ['iphone'],
#  ['html', 'javascript', 'jquery', 'sso'],
#  ['cc.complexity-theory', 'complexity-classes'],
#  ['css', 'html', 'javascript'],
#  ['backup', 'settings', 'vmware-esxi'],
#  ['database', 'microsoft-access', 'oracle', 'sql'],
#  ['audio', 'avaudioplayer', 'iphone', 'mixing'],
#  ['linux-kernel', 'netlink', 'operating-system', 'sockets'],
#  ['.net', 'javascript', 'typescript'],
#  ['grub2', 'ubuntu'],
#  ['db2', 'query', 'reindex', 'table'],
#  ['apple', 'ios-simulator', 'ios5', 'ipad'],
#  ['mysql', 'mysql-error-1054', 'vbulletin'],
#  ['capistrano'],
#  ['python', 'xpath', 'xslt'],
#  ['perl', 'string'],
#  [],
#  ['newline', 'php', 'strpos'],
#  ['co-workers', 'jobs'],
#  ['yii'],
#  ['javascript'],
#  [],
#  ['hibernate'],
#  ['c#', 'log4net'],
#  ['jquery'],
#  ['ruby-on-rails', 'ruby-on-rails-3', 'shopify'],
#  ['carbon', 'cocoa', 'osx'],
#  ['flex3', 'flexbuilder'],
#  ['javascript', 'jquery'],
#  ['postgresql', 'security'],
#  ['.net', '.net-2.0', 'c#', 'linux', 'mono'],
#  ['objective-c'],
#  ['hammer', 'rtt', 'wireshark'],
#  ['join', 'php', 'sql-server'],
#  ['django', 'django-templates', 'image', 'python'],
#  ['facebook-like'],
#  ['internet-explorer-6'],
#  ['c++', 'ide', 'linux', 'templates'],
#  [],
#  [],
#  [],
#  ['c', 'environment-variables', 'visual-studio'],
#  ['asp.net', 'c#', 'visual-studio-2010'],
#  ['ajax', 'getjson', 'jquery', 'json'],
#  ['r', 'time-series'],
#  ['blend', 'expression-blend', 'silverlight'],
#  [],
#  ['android', 'android-layout'],
#  ['category-theory', 'examples-counterexamples', 'probability'],
#  ['chmod', 'mac', 'osx', 'permissions'],
#  ['full-text-search', 'performance', 'postgresql'],
#  ['git', 'ssh'],
#  ['defragment', 'windows-vista'],
#  [],
#  [],
#  ['active-directory', 'new-account', 'password', 'user-accounts'],
#  ['multithreading', 'python', 'queue', 'thread-safety'],
#  ['cocoa-touch', 'ios', 'nsdate'],
#  ['amazon', 'android', 'in-app-purchase'],
#  ['c#', 'size', 'types'],
#  ['dependency-injection', 'java', 'spring'],
#  ['asp.net', 'asp.net-mvc'],
#  [],
#  ['base-class', 'c++', 'derived-class', 'inheritance'],
#  ['.net', 'activex', 'c#', 'winforms'],
#  ['ios5', 'unity3d', 'xcode4'],
#  [],
#  ['.net', 'couchbase', 'membase', 'memcached', 'ruby'],
#  ['glteximage2d', 'opengl'],
#  ['firefox-addon', 'javascript', 'right-click'],
#  ['android', 'imageview'],
#  ['database-design', 'database-schema', 'mongodb', 'ruby-on-rails-3'],
#  ['formatting', 'gis', 'gpx', 'schema', 'xml'],
#  [],
#  ['tfs', 'uninstall', 'visual-studio-2010'],
#  ['abstract-algebra', 'hopf-algebras', 'quantum-groups'],
#  ['database', 'filenames', 'image'],
#  ['differential-equations',
#   'power-series',
#   'real-analysis',
#   'special-functions'],
#  ['mysql', 'python'],
#  ['calculus', 'definite-integral', 'homework'],
#  ['visual-studio'],
#  ['composition', 'scala', 'traits'],
#  [],
#  ['android', 'asp.net', 'iphone'],
#  ['dom', 'get', 'html', 'index', 'jquery'],
#  ['linux', 'scp', 'ssh', 'unix'],
#  [],
#  ['facebook',
#   'facebook-fql',
#   'facebook-graph-api',
#   'nokogiri',
#   'ruby-on-rails'],
#  ['objective-c'],
#  ['c++', 'memory', 'pointers'],
#  ['equivalent', 'jquery', 'prototypejs'],
#  ['ios'],
#  [],
#  ['folder', 'windows-xp'],
#  ['deployment', 'java', 'packages'],
#  [],
#  ['silverlight', 'wcf', 'wpf'],
#  ['teradata'],
#  [],
#  ['post'],
#  ['cocoa', 'cocoa-touch', 'iphone'],
#  ['.net', 'c#', 'iqueryable', 'linq', 'linq-to-entities'],
#  ['action', 'ipad', 'objective-c', 'selector', 'uibutton'],
#  ['django', 'model'],
#  ['c++', 'qt'],
#  ['comet', 'orbited', 'python', 'stomp', 'twisted'],
#  ['c#', 'file-permissions', 'impersonation', 'windows-identity'],
#  [],
#  ['java', 'stax', 'xml'],
#  ['algorithm', 'directed-graph', 'graph-algorithm'],
#  ['java', 'jvmti', 'multithreading'],
#  ['cracking', 'key-generator', 'reverse-engineering', 'software-protection'],
#  ['c#', 'orchardcms'],
#  ['c#', 'garbage-collection'],
#  ['android', 'ios', 'qr-code'],
#  ['c#'],
#  ['jeditorpane', 'netbeans', 'platform', 'standalone', 'swing'],
#  ['ajax', 'rest', 'ruby-on-rails'],
#  ['books', 'ebook', 'ruby', 'ruby-on-rails'],
#  [],
#  ['cocoa-touch', 'nsstring', 'objective-c', 'string-comparison'],
#  ['div', 'event-handling', 'events', 'jquery-live'],
#  ['cluster-computing', 'image', 'mysql', 'php'],
#  ['c#', 'localization', 'usercontrols', 'winforms'],
#  ['image-scaling', 'php'],
#  ['c#', 'removing-whitespace', 'replace', 'string', 'whitespace'],
#  [],
#  ['file-management', 'symbolic-link'],
#  ['django', 'django-cms', 'internationalization'],
#  [],
#  ['memory', 'python'],
#  ['virtualization'],
#  ['ios', 'ipad', 'iphone', 'objective-c'],
#  ['javascript'],
#  ['category-theory', 'logic', 'type-theory'],
#  [],
#  [],
#  ['asp.net', 'entity-framework-4', 'linq-to-entities'],
#  [],
#  ['.net', 'soap', 'wcf', 'web-services'],
#  ['sql-server-2008'],
#  ['ejb', 'java', 'spring'],
#  ['flags', 'gcc', 'runtime'],
#  ['emacs'],
#  [],
#  ['mathematica', 'workbench'],
#  ['numpy', 'python', 'windows'],
#  ['core-data', 'iphone', 'nsmanagedobjectcontext', 'uitableview'],
#  ['code-search-engine', 'html', 'javascript', 'search-engine'],
#  ['.net', 'wpf'],
#  ['adobe', 'flex', 'versioning'],
#  ['ruby-on-rails'],
#  ['arrays', 'php'],
#  ['coffeescript', 'node.js', 'socket.io', 'web-applications', 'web-services'],
#  ['directory', 'glob', 'mkdir', 'php'],
#  ['html5', 'html5-video', 'video', 'video-processing', 'video-streaming'],
#  ['.net', 'c#-4.0', 'crystal-reports', 'wpf'],
#  ['mysql', 'php'],
#  [],
#  ['appdomain', 'c#', 'marshalling', 'multithreading'],
#  [],
#  ['attributes',
#   'database-design',
#   'maintainability',
#   'pattern-recognition',
#   'robustness'],
#  [],
#  ['css', 'html5'],
#  ['ascx', 'asp.net', 'c#', 'vb.net'],
#  ['calculus', 'homework'],
#  ['windows-7', 'windows-registry'],
#  ['git'],
#  ['batch', 'batch-file', 'compression', 'jpeg'],
#  ['asp-classic', 'asp.net', 'sql', 'vbscript'],
#  [],
#  ['search', 'segmentation-fault'],
#  ['linear-algebra', 'matrices'],
#  ['c++', 'winapi', 'windows'],
#  ['canvas', 'drag', 'draggable', 'html5'],
#  ['tikz-pgf'],
#  ['ssh', 'windows'],
#  ['artificial-intelligence', 'c#'],
#  [],
#  ['iphone-sdk-4.0', 'objective-c'],
#  [],
#  ['dd-wrt', 'networking', 'wireless-network'],
#  [],
#  ['hostname', 'networking'],
#  ['php'],
#  ['android'],
#  ['callback', 'forms', 'php', 'post', 'url'],
#  ['git', 'svn'],
#  ['php5', 'sql'],
#  ['gpu', 'identification'],
#  ['javascript', 'minify', 'squishit'],
#  [],
#  ['.net', 'c#', 'http-headers', 'rest', 'wcf'],
#  ['android'],
#  ['grep', 'macvim', 'vim'],
#  ['javascript'],
#  ['asp.net', 'crystal-reports', 'vb.net'],
#  ['composer-php', 'dependency-management', 'symfony2'],
#  ['google-app-engine', 'google-fusion-tables', 'postgresql'],
#  [],
#  ['jquery', 'jquery-mobile', 'mobile', 'web-interface'],
#  ['amazon-cloudsearch', 'amazon-web-services', 'cloud', 'java'],
#  ['file-sharing', 'file-transfer', 'windows'],
#  ['rspec', 'ruby'],
#  ['e-commerce', 'products', 'web-applications'],
#  ['keymap', 'mac', 'osx', 'spaces'],
#  [],
#  ['clang', 'gcc', 'xcode'],
#  ['cookies', 'javascript'],
#  ['bash', 'shell', 'unix'],
#  ['css', 'css-selectors', 'html', 'last-child', 'stylesheet'],
#  ['php', 'python'],
#  ['cad', 'docking-station', 'laptop', 'multiple-monitors'],
#  ['cropping', 'django', 'image'],
#  ['php'],
#  ['java'],
#  ['java', 'multithreading'],
#  ['css', 'internet-explorer-9', 'negative-margin'],
#  ['c++', 'virtual', 'vtable'],
#  ['events'],
#  ['c++'],
#  [],
#  [],
#  ['c++'],
#  ['appliance', 'hardware', 'pdf', 'scanner', 'scanning'],
#  ['mysql', 'php', 'sql'],
#  ['arraylist', 'java'],
#  ['devexpress', 'gridview', 'winforms'],
#  ['adobe', 'digital-signature', 'pdf', 'signature'],
#  ['redmine'],
#  [],
#  [],
#  [],
#  ['binaryfiles', 'excel'],
#  ['fluent-nhibernate', 'icriteria', 'nhibernate', 'nhibernate-mapping'],
#  ['algorithm'],
#  [],
#  ['fold', 'scala'],
#  ['c#', 'sockets'],
#  ['php'],
#  ['ruby-on-rails'],
#  ['dhcp-server', 'failover', 'isc-dhcp', 'nagios', 'status'],
#  ['logging', 'nginx', 'performance'],
#  ['optimization'],
#  ['ios', 'ipad', 'iphone', 'twitter'],
#  ['hibernate', 'hql', 'sql'],
#  ['apache', 'encoding', 'mysql', 'php', 'utf-8'],
#  ['spotify'],
#  ['mysql', 'php', 'syntax-error', 'while-loop'],
#  ['c#', 'regex'],
#  [],
#  ['zend-search-lucene'],
#  [],
#  ['distribution', 'mysql'],
#  ['probability', 'probability-theory', 'statistics'],
#  ['fonts', 'pgfplots'],
#  ['append', 'html', 'javascript', 'jquery', 'nth-child'],
#  ['mac', 'macosx', 'nginx'],
#  ['perl', 'php'],
#  ['java', 'java.util.concurrent', 'jboss7.x', 'multithreading'],
#  [],
#  ['cryptography', 'encryption', 'pgp'],
#  ['javascript', 'jquery'],
#  ['aop', 'apache-camel', 'debugging', 'java', 'trace'],
#  [],
#  ['junit4', 'spring-test', 'testing'],
#  ['centos', 'dns', 'nameserver', 'whm'],
#  ['vb.net', 'visual-studio-2010'],
#  ['linguistics', 'tikz-qtree', 'trees'],
#  ['ajax', 'base64', 'canvas', 'php'],
#  ['iphone', 'iphone-sdk-3.0', 'objective-c'],
#  ['codeigniter', 'image-gallery', 'jquery', 'php'],
#  ['eager-loading', 'mongomapper', 'ruby'],
#  ['c', 'quine'],
#  ['php', 'security'],
#  ['c++', 'stl', 'visual-studio'],
#  ['c#', 'directx', 'screen-capture'],
#  ['banach-spaces', 'hilbert-spaces', 'real-analysis'],
#  ['backup', 'operating-systems'],
#  ['boot', 'hp'],
#  ['java'],
#  ['phonegap'],
#  ['doctrine', 'doctrine2', 'php'],
#  ['localization', 'php', 'unicode'],
#  ['c++'],
#  ['cegui', 'ios', 'ogre', 'osx'],
#  ['geolocation', 'ip-geolocation'],
#  ['checkpoint',
#   'cluster-computing',
#   'distributed-computing',
#   'java',
#   'synchronization'],
#  ['linq'],
#  ['django', 'python'],
#  ['java', 'methods'],
#  ['css', 'menubar', 'wordpress'],
#  ['ics', 'mime-types', 'php', 'upload'],
#  ['asp.net-mvc', 'asp.net-mvc-3', 'ef-code-first', 'tdd', 'unit-testing'],
#  ['c++', 'maintainability', 'optimization'],
#  ['css', 'html', 'png', 'rendering', 'text-mode'],
#  ['java', 'port', 'sockets'],
#  ['html', 'php'],
#  [],
#  ['c++', 'casting'],
#  ['math-mode', 'math-operators', 'stack'],
#  ['jquery', 'scroll', 'scrollto'],
#  ['php'],
#  ['cuda', 'gpu'],
#  [],
#  ['r'],
#  ['cucumber'],
#  ['gsub', 'regex', 'ruby'],
#  ['pde'],
#  ['adobe'],
#  [],
#  ['coldfusion-8', 'disabled-input', 'rtf'],
#  [],
#  [],
#  ['agent',
#   'algorithm',
#   'artificial-intelligence',
#   'first-order-logic',
#   'logic'],
#  ['algorithm', 'language-agnostic', 'particle-filter', 'probability'],
#  ['asp.net', 'c#', 'regex'],
#  [],
#  ['linux', 'xen'],
#  [],
#  ['ajax', 'struts2'],
#  ['android', 'android-widget'],
#  ['canvas', 'java', 'swing'],
#  ['activity', 'android', 'java'],
#  ['ios', 'objective-c', 'sqlite'],
#  ['amazon-ec2'],
#  ['canvas', 'overlap', 'overlay', 'raphael'],
#  ['sas'],
#  ['comma', 'counter', 'javascript'],
#  [],
#  ['email', 'forms', 'php', 'post', 'submit'],
#  ['macports', 'osx', 'rsync', 'terminal'],
#  ['regex'],
#  ['c++', 'mouse', 'sdl', 'slider', 'trackbar'],
#  ['database', 'persistence', 'workflow-foundation'],
#  ['javascript', 'jquery', 'php'],
#  ['android', 'animation', 'listview'],
#  ['javascript', 'regex'],
#  ['.htaccess', 'cron', 'cron-task', 'password-protection', 'wget'],
#  ['javascript'],
#  ['batch', 'batch-file', 'thunderbird'],
#  ['boost-regex', 'c++', 'dll', 'icu'],
#  [],
#  ['code-generation', 'java', 'latex'],
#  ['aix', 'c', 'gcc'],
#  ['asp.net', 'c#', 'caching'],
#  ['baby-photos', 'outdoor', 'post-processing', 'workflow'],
#  ['denyhosts', 'fail2ban', 'security', 'ubuntu-10.04'],
#  ['c++', 'frequency-analysis', 'm4a', 'mp3'],
#  ['asp.net'],
#  ['css', 'html'],
#  [],
#  ['html', 'html-parsing'],
#  ['custom-build-step', 'setup-project', 'visual-studio-2008'],
#  ['android'],
#  ['ip', 'java', 'subnet'],
#  [],
#  ['configuration', 'opengl', 'qt'],
#  ['wpf', 'xbap'],
#  ['ios', 'iphone', 'objective-c'],
#  ['comments', 'standards', 'visual-studio-2008'],
#  ['arrays', 'javascript', 'loops', 'variables'],
#  ['c#'],
#  ['bash', 'bash-scripting', 'sudo'],
#  [],
#  ['f#', 'type-inference'],
#  ['database-design', 'mysql', 'oracle', 'sql-server'],
#  ['real-analysis'],
#  ['arrays', 'date', 'php'],
#  ['frameworks', 'mvc', 'php', 'symfony'],
#  ['apache2', 'gzip', 'mod-rewrite'],
#  ['api', 'cross-platform', 'rest'],
#  ['.net', 'c#', 'saml', 'sso', 'xml'],
#  [],
#  ['interface-builder', 'ios', 'iphone'],
#  ['ace', 'c++'],
#  ['algorithm', 'arrays', 'dynamic-programming', 'sub-arrays'],
#  ['base', 'hotlinking', 'href', 'xml'],
#  ['blogs', 'embed', 'javascript', 'joomla', 'joomla1.5'],
#  ['javascript', 'youtube'],
#  ['.htaccess', 'header', 'http', 'php'],
#  ['coldfusion', 'forms', 'option', 'sql'],
#  ['android', 'blackberry', 'iphone', 'smartphone', 'web-applications'],
#  ['asp.net', 'updatepanel'],
#  ['php'],
#  ['.net', 'asp.net', 'treeview'],
#  ['sql', 'vb.net'],
#  [],
#  ['core-data', 'iphone'],
#  ['binary', 'binding', 'ivalueconverter'],
#  ['gps', 'iphone', 'javascript', 'web-applications'],
#  ['windows-xp'],
#  ['compression', 'gzip', 'linux'],
#  ['android', 'android-images', 'android-imageview'],
#  ['javascript'],
#  ['entity-framework',
#   'entity-framework-4',
#   'sql',
#   'sql-server',
#   'sql-server-2008'],
#  ['ilist', 'iqueryable', 'linq', 'select'],
#  [],
#  ['mysql', 'python'],
#  ['iis', 'iis7'],
#  ['jquery', 'prototypejs'],
#  ['tortoisegit'],
#  ['wireless-networking', 'wps'],
#  ['apache2', 'httpd.conf', 'linux', 'php', 'virtual-directory'],
#  ['data-binding', 'pdo', 'php'],
#  ['macports', 'osx', 'ruby', 'ruby-on-rails', 'rubygems'],
#  ['html', 'jquery'],
#  ['android', 'skype'],
#  ['android'],
#  ['c++'],
#  [],
#  ['css', 'magento'],
#  ['arrays', 'java', 'static'],
#  ['c', 'gcc', 'performance'],
#  ['browser', 'javascript', 'selected-text'],
#  ['javascript', 'phonegap', 'scrollbar'],
#  [],
#  ['jquery'],
#  ['java-me', 'lwuit'],
#  ['lotus-notes'],
#  ['java', 'map', 'nullpointerexception'],
#  ['silverlight', 'visual-studio-2010'],
#  ['c++', 'destructor', 'sdl', 'tick'],
#  ['python'],
#  ['close', 'database-connection', 'destructor', 'java'],
#  ['integer', 'python', 'random'],
#  [],
#  ['core-data', 'ios'],
#  ['mtu', 'tp-link', 'wireless-router'],
#  ['linux'],
#  ['block', 'prestashop'],
#  ['c++', 'c++11', 'initializer-list', 'unions'],
#  ['android', 'eclipse', 'xml'],
#  ['c#', 'mongodb'],
#  ...]

# %%
from sklearn.metrics import f1_score
#The score is predicted on Train data.
#weighted: Calculate metrics for each label, and find their average, weighted by support (the number of true instances for each label). 
#This alters ‘macro’ to account for label imbalance; it can result in an F-score that is not between precision and recall.
#Predict the accuracy on the train set
f1_score(predicted,Y, average='weighted')
# Out:
# 0.91959012867433809

# %%
#Micro: Calculate metrics globally by counting the total true positives, false negatives and false positives.
f1_score(predicted,Y, average='micro')
# Out:
# 0.89666515426497284

# %%
#Here I was trying to see the association rules in the body and Title sections. However, this section of the code did not produced 
#desired outcomes.

# %%
#Trying to fit association rules
#from pyspark.ml.fpm import FPGrowth
#TagsfpGrowth = FPGrowth(itemsCol="tokenizedTags")
#modelFPGrowth = TagsfpGrowth.fit(workingTrain)

# %%
#modelFPGrowth.associationRules.show()
#modelFPGrowth.freqItemsets.show()

# %%
#modelFPGrowth.transform(workingTrain).show()

# %%
#modelFPGrowth.associationRules.show()
